# %% [markdown]
# # CrowdTruth metrics 2.0 documentation
#
# Let:
#
# * $workers(u):$ all workers that annotate media unit $u$;
# * $units(i):$ all input media units annotated by worker $i$;
# * $WorkVec(i, u):$ annotations of worker $i$ on media unit $u$ as a binary vector;
# * $MediaUnitVec(s) = \sum_{i \in workers(s)} WorkVec(i,s)$, where $s$ is an input media unit.
#
# ## Media Unit Quality Score (UQS)
#
# The unit quality score $UQS(u)$ is computed as the average cosine similarity between all worker vectors for a given input media unit $u$, weighted by the worker quality ($WQS$) and annotation quality ($AQS$). The goal is to capture the degree of agreement in annotating the media unit. Through the weighted average, workers and annotations with lower quality will have less of an impact on the final score.
#
# $$ UQS(u) = \frac{\sum_{i, j \in workers(u)} Wcos(WorkVec(i,u), WorkVec(j,u)) \; WQS(i) \; WQS(j)}{\sum_{i, j \in workers(u)} WQS(i) \; WQS(j)}, \; i \neq j.$$
#
#
# ### Weighted Cosine
#
# To weigh the metrics with the annotation quality, we compute $Wcos$, the weighted version of the cosine similarity. This metric is only applicable to closed tasks, where annotation quality can be calculated across media units. For open-ended tasks, we consider annotation quality equal to 1 and calculate the regular cosine similarity.
#
# $$ Wcos(vec_1, vec_2) = \frac{\sum_{a} vec_1(a) \; vec_2(a) \; AQS(a)}{\sqrt{(\sum_{a} vec_1^2(a) \; AQS(a)) \; (\sum_{a} vec_2^2(a) \; AQS(a))}} .$$
#
#
# ## Worker Quality Score (WQS)
#
# The worker quality score $WQS(i)$ for a given worker $i$ is the product of 2 separate metrics - the worker-worker agreement $WWA(i)$ and the worker-media unit agreement $WUA(i)$.
#
# $$ WQS(i) = WUA(i) \; WWA(i) .$$
#
# ### Worker-Media Unit Agreement
#
# The worker-media unit agreement $WUA(i)$ is the average cosine distance between the annotations of a worker $i$ and all annotations for the media units they have worked on, weighted by the media unit and annotation quality. It calculates how much a worker disagrees with the crowd on a media unit basis. Through the weighted average, media units and anntation with lower quality will have less of an impact on the final score.
#
# $$ WSA(i) = \frac{\sum_{u \in units(i)} Wcos(WorkVec(i,u), MediaUnitVec(u) - WorkVec(i, u)) \; UQS(u)}{\sum_{u \in units(i)} UQS(u)} .$$
#
# ### Worker-Worker Agreement
#
# The worker-worker agreement $WWA(i)$ is the average cosine distance between the annotations of a worker $i$ and all other workers that have worked on the same media units as worker $i$, weighted by the worker and annotation qualities. The metric gives an indication as to whether there are consisently like-minded workers. This is useful for identifying communities of thought. Through the weighted average, workers and annotations with lower quality will have less of an impact on the final score of the given worker.
#
# $$ WWA(i) = \frac{ \sum_{j \in workers(u \in units(i))} Wcos(WorkVec(i, u), WorkVec(j, u)) \; WQS(j) \; UQS(u) }{ \sum_{j \in workers(s \in units(i))} WQS(j) \; UQS(u) }, \; i \neq j .$$
#
#
# ## Annotation Quality Score (AQS)
#
# The annotation quality score $AQS(a)$ calculates the agreement of selecting an annotation $a$, over all the media units it appears in. Therefore, it is only applicable to closed tasks, where the same annotation set is used for all input media units. It is based on $P_a(i | j)$, the probability that if a worker $j$ annotates $a$ in a media unit, worker $i$ will also annotate it.
#
# $$ P_a(i | j) = \frac{ \sum_{u \in units(i) \cap units(j) } UQS(u) \; WorkVec(i, s)(r) \; WorkVec(j, s)(r) }{ \sum_{u \in units(i) \cap units(j) } UQS(u) \; WorkVec(j, u)(r) } . $$
#
# $AQS(a)$ is the weighted average of $P_a(i | j)$ for all possible pairs of workers. Through the weighted average, input media units and workers with lower quality will have less of an impact on the final score of the annotation.
#
# $$ AQS(a) = \frac{ \sum_{i,j} WQS(i) \; WQS(j) \; P_a(i | j) }{ \sum_{i,j} WQS(i) \; WQS(j) }, i \neq j . $$
#
#
# ## Media Unit-Annotation Score (UAS)
#
# The media unit - annotation score $UAS(u, a)$ calculates the likelihood that annotation $a$ is expressed in input media unit $u$. It is the ratio of the number of workers that picked annotation $u$ over all workers that annotated the unit, weighted by the worker quality.
#
# $$ UAS(u, a) = \frac{ \sum_{i \in workers(u)} WorkVec(i,u)(a) \; WQS(i) }{ \sum_{i \in workers(u)} WQS(i) }. $$

# %% [markdown]
# # How to run the metrics

# %%
# Read data
import pandas as pd

pd.set_option('display.max_columns', None)
passages_per_article_ordered_filename = "AnalysisFiles/2P_WithoutHighlight_Passages_Ordered/ordered_passages_noHighlight_15workers.csv"
passages_per_article_ordered_dataset = pd.read_csv(passages_per_article_ordered_filename)

passages_per_article_ordered_dataset.head(10)
# Out:
#      _unit_id          _created_at         _id          _started_at _tainted  \
# 0  1429458495  10/28/2017 20:31:41  2966966110  10/28/2017 20:30:09    False
# 1  1429458495  10/28/2017 22:15:17  2967118333  10/28/2017 22:13:56    False
# 2  1429458495  10/29/2017 00:19:13  2967308325  10/29/2017 00:18:24    False
# 3  1429458495  10/29/2017 01:59:25  2967450676  10/29/2017 01:58:05    False
# 4  1429458495  10/29/2017 02:39:25  2967502293  10/29/2017 02:38:02    False
# 5  1429458495  10/29/2017 05:08:27  2967648248  10/29/2017 05:07:17    False
# 6  1429458495  10/29/2017 06:02:16  2967691664  10/29/2017 06:01:31    False
# 7  1429458495  10/29/2017 09:45:41  2967824507  10/29/2017 09:45:20    False
# 8  1429458495  10/29/2017 09:52:17  2967828678  10/29/2017 09:51:38    False
# 9  1429458495  10/29/2017 09:59:26  2967833239  10/29/2017 09:58:34    False
#
#          _channel  _trust  _worker_id _country _region         _city  \
# 0      coinworker       1    41920197      USA      NY       Buffalo
# 1         instagc       1    15193250      USA      SC       Chesnee
# 2         prodege       1     1924522      USA      NY      New York
# 3  gifthunterclub       1    43999669      USA      NY      New York
# 4      fusioncash       1    41545007      USA      NV     Las Vegas
# 5         instagc       1    29289135      CAN      QC      Brossard
# 6      bitcoinget       1    43891892      USA      NJ  North Bergen
# 7         prodege       1    15965551      GBR     NaN           NaN
# 8         instagc       1    18985376      GBR      D2         Derby
# 9      bitcoinget       1    43907115      USA      CA      San Jose
#
#               _ip  hiddeninput  highlighted1  highlighted2  highlighted3  \
# 0   192.3.224.227          NaN           NaN           NaN           NaN
# 1    204.116.1.23          NaN           NaN           NaN           NaN
# 2    108.54.58.89          NaN           NaN           NaN           NaN
# 3  165.227.57.139          NaN           NaN           NaN           NaN
# 4    24.120.53.14          NaN           NaN           NaN           NaN
# 5   174.91.251.46          NaN           NaN           NaN           NaN
# 6  192.241.129.19          NaN           NaN           NaN           NaN
# 7  109.181.31.157          NaN           NaN           NaN           NaN
# 8   81.108.86.170          NaN           NaN           NaN           NaN
# 9  166.88.123.180          NaN           NaN           NaN           NaN
#
#    highlighted4  highlighted5             notrelevant_snippets  relevance_s1  \
# 0           NaN           NaN                      ["s2","s5"]           NaN
# 1           NaN           NaN                               []           NaN
# 2           NaN           NaN  ["s1","s2","s3","s4","s5","s6"]           NaN
# 3           NaN           NaN                               []           NaN
# 4           NaN           NaN                               []           NaN
# 5           NaN           NaN                 ["s1","s2","s5"]           NaN
# 6           NaN           NaN  ["s1","s2","s3","s4","s5","s7"]           NaN
# 7           NaN           NaN                 ["s1","s2","s3"]           NaN
# 8           NaN           NaN  ["s1","s2","s3","s4","s5","s6"]           NaN
# 9           NaN           NaN                           ["s4"]           NaN
#
#    relevance_s2  relevance_s3  relevance_s4  relevance_s5  \
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN
#
#       relevant_snippets  bin  doc_len  \
# 0        s1,s3,s4,s6,s7    2      578
# 1  s1,s2,s3,s4,s5,s6,s7    2      578
# 2                    s7    2      578
# 3  s1,s2,s3,s4,s5,s6,s7    2      578
# 4  s1,s2,s3,s4,s5,s6,s7    2      578
# 5           s3,s4,s6,s7    2      578
# 6                    s6    2      578
# 7           s4,s5,s6,s7    2      578
# 8                    s7    2      578
# 9     s1,s2,s3,s5,s6,s7    2      578
#
#                                        document_body  document_id  \
# 0  <p>The earnest figures speaking to us from the...       918882
# 1  <p>The earnest figures speaking to us from the...       918882
# 2  <p>The earnest figures speaking to us from the...       918882
# 3  <p>The earnest figures speaking to us from the...       918882
# 4  <p>The earnest figures speaking to us from the...       918882
# 5  <p>The earnest figures speaking to us from the...       918882
# 6  <p>The earnest figures speaking to us from the...       918882
# 7  <p>The earnest figures speaking to us from the...       918882
# 8  <p>The earnest figures speaking to us from the...       918882
# 9  <p>The earnest figures speaking to us from the...       918882
#
#        document_title  hiddeninput_gold  highlighted1_gold  highlighted2_gold  \
# 0  Gateway to Madness               NaN                NaN                NaN
# 1  Gateway to Madness               NaN                NaN                NaN
# 2  Gateway to Madness               NaN                NaN                NaN
# 3  Gateway to Madness               NaN                NaN                NaN
# 4  Gateway to Madness               NaN                NaN                NaN
# 5  Gateway to Madness               NaN                NaN                NaN
# 6  Gateway to Madness               NaN                NaN                NaN
# 7  Gateway to Madness               NaN                NaN                NaN
# 8  Gateway to Madness               NaN                NaN                NaN
# 9  Gateway to Madness               NaN                NaN                NaN
#
#    highlighted3_gold  highlighted4_gold  highlighted5_gold  index  \
# 0                NaN                NaN                NaN      7
# 1                NaN                NaN                NaN      7
# 2                NaN                NaN                NaN      7
# 3                NaN                NaN                NaN      7
# 4                NaN                NaN                NaN      7
# 5                NaN                NaN                NaN      7
# 6                NaN                NaN                NaN      7
# 7                NaN                NaN                NaN      7
# 8                NaN                NaN                NaN      7
# 9                NaN                NaN                NaN      7
#
#    notrelevant_snippets_gold  rel  relevance_s1_gold  relevance_s2_gold  \
# 0                        NaN    2                NaN                NaN
# 1                        NaN    2                NaN                NaN
# 2                        NaN    2                NaN                NaN
# 3                        NaN    2                NaN                NaN
# 4                        NaN    2                NaN                NaN
# 5                        NaN    2                NaN                NaN
# 6                        NaN    2                NaN                NaN
# 7                        NaN    2                NaN                NaN
# 8                        NaN    2                NaN                NaN
# 9                        NaN    2                NaN                NaN
#
#    relevance_s3_gold  relevance_s4_gold  relevance_s5_gold  \
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3                NaN                NaN                NaN
# 4                NaN                NaN                NaN
# 5                NaN                NaN                NaN
# 6                NaN                NaN                NaN
# 7                NaN                NaN                NaN
# 8                NaN                NaN                NaN
# 9                NaN                NaN                NaN
#
#    relevant_snippets_gold           sentence0  \
# 0                     NaN  Gateway to Madness
# 1                     NaN  Gateway to Madness
# 2                     NaN  Gateway to Madness
# 3                     NaN  Gateway to Madness
# 4                     NaN  Gateway to Madness
# 5                     NaN  Gateway to Madness
# 6                     NaN  Gateway to Madness
# 7                     NaN  Gateway to Madness
# 8                     NaN  Gateway to Madness
# 9                     NaN  Gateway to Madness
#
#                                            sentence1 sentence10 sentence11  \
# 0  The earnest figures speaking to us from the vi...        NaN        NaN
# 1  The earnest figures speaking to us from the vi...        NaN        NaN
# 2  The earnest figures speaking to us from the vi...        NaN        NaN
# 3  The earnest figures speaking to us from the vi...        NaN        NaN
# 4  The earnest figures speaking to us from the vi...        NaN        NaN
# 5  The earnest figures speaking to us from the vi...        NaN        NaN
# 6  The earnest figures speaking to us from the vi...        NaN        NaN
# 7  The earnest figures speaking to us from the vi...        NaN        NaN
# 8  The earnest figures speaking to us from the vi...        NaN        NaN
# 9  The earnest figures speaking to us from the vi...        NaN        NaN
#
#   sentence12 sentence13 sentence14 sentence15 sentence16 sentence17  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
# 5        NaN        NaN        NaN        NaN        NaN        NaN
# 6        NaN        NaN        NaN        NaN        NaN        NaN
# 7        NaN        NaN        NaN        NaN        NaN        NaN
# 8        NaN        NaN        NaN        NaN        NaN        NaN
# 9        NaN        NaN        NaN        NaN        NaN        NaN
#
#   sentence18 sentence19                                          sentence2  \
# 0        NaN        NaN  Some find it shocking that a technically gifte...
# 1        NaN        NaN  Some find it shocking that a technically gifte...
# 2        NaN        NaN  Some find it shocking that a technically gifte...
# 3        NaN        NaN  Some find it shocking that a technically gifte...
# 4        NaN        NaN  Some find it shocking that a technically gifte...
# 5        NaN        NaN  Some find it shocking that a technically gifte...
# 6        NaN        NaN  Some find it shocking that a technically gifte...
# 7        NaN        NaN  Some find it shocking that a technically gifte...
# 8        NaN        NaN  Some find it shocking that a technically gifte...
# 9        NaN        NaN  Some find it shocking that a technically gifte...
#
#   sentence20                                          sentence3  \
# 0        NaN  But technical expertise is no proof against bi...
# 1        NaN  But technical expertise is no proof against bi...
# 2        NaN  But technical expertise is no proof against bi...
# 3        NaN  But technical expertise is no proof against bi...
# 4        NaN  But technical expertise is no proof against bi...
# 5        NaN  But technical expertise is no proof against bi...
# 6        NaN  But technical expertise is no proof against bi...
# 7        NaN  But technical expertise is no proof against bi...
# 8        NaN  But technical expertise is no proof against bi...
# 9        NaN  But technical expertise is no proof against bi...
#
#                                            sentence4  \
# 0  Experts on cult behavior are already exploring...
# 1  Experts on cult behavior are already exploring...
# 2  Experts on cult behavior are already exploring...
# 3  Experts on cult behavior are already exploring...
# 4  Experts on cult behavior are already exploring...
# 5  Experts on cult behavior are already exploring...
# 6  Experts on cult behavior are already exploring...
# 7  Experts on cult behavior are already exploring...
# 8  Experts on cult behavior are already exploring...
# 9  Experts on cult behavior are already exploring...
#
#                                            sentence5  \
# 0  There was an old-fashioned element to the psyc...
# 1  There was an old-fashioned element to the psyc...
# 2  There was an old-fashioned element to the psyc...
# 3  There was an old-fashioned element to the psyc...
# 4  There was an old-fashioned element to the psyc...
# 5  There was an old-fashioned element to the psyc...
# 6  There was an old-fashioned element to the psyc...
# 7  There was an old-fashioned element to the psyc...
# 8  There was an old-fashioned element to the psyc...
# 9  There was an old-fashioned element to the psyc...
#
#                                            sentence6  \
# 0  Cults differ from mainstream faiths in their l...
# 1  Cults differ from mainstream faiths in their l...
# 2  Cults differ from mainstream faiths in their l...
# 3  Cults differ from mainstream faiths in their l...
# 4  Cults differ from mainstream faiths in their l...
# 5  Cults differ from mainstream faiths in their l...
# 6  Cults differ from mainstream faiths in their l...
# 7  Cults differ from mainstream faiths in their l...
# 8  Cults differ from mainstream faiths in their l...
# 9  Cults differ from mainstream faiths in their l...
#
#                                            sentence7 sentence8 sentence9  \
# 0  The interesting thing about Branch Davidians, ...       NaN       NaN
# 1  The interesting thing about Branch Davidians, ...       NaN       NaN
# 2  The interesting thing about Branch Davidians, ...       NaN       NaN
# 3  The interesting thing about Branch Davidians, ...       NaN       NaN
# 4  The interesting thing about Branch Davidians, ...       NaN       NaN
# 5  The interesting thing about Branch Davidians, ...       NaN       NaN
# 6  The interesting thing about Branch Davidians, ...       NaN       NaN
# 7  The interesting thing about Branch Davidians, ...       NaN       NaN
# 8  The interesting thing about Branch Davidians, ...       NaN       NaN
# 9  The interesting thing about Branch Davidians, ...       NaN       NaN
#
#    topic                                  topic_description      topic_query
# 0    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 1    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 2    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 3    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 4    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 5    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 6    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 7    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 8    325  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 9    325  Describe a cult by name and identify the cult ...  Cult Lifestyles

# %% [markdown]
# ### Creating a class that inherits from `Configuration` lets us define how the input file will be processed:
#
# * `inputColumns`: list of input columns from the .csv file, the input that the workers were shown
# * `outputColumns`: list of output columns with the answers from the workers
# * `processJudgments`: function that defines how the worker judgments wil be processed; default separator for judgments is ','
#
# To build the annotation vector, we also need to specify whether this is an **open-ended** or **closed** task, using the `open_ended_task` variable.
#
# * **open-ended task** means that the annotation space is not known, and workers can freely provide all the choices that apply (e.g. in sound tagging, the workers are provided with a text box to enter all tags they can think of)
# * **closed task** means that the annotations that can occur in the data are already known, and the workers are asked to validate their existence (e.g. for medical relation extraction, the workers pick from a pre-defined multiple-choice set of relations)
#
# If the task we are processing is **closed**, then we also need to provide the list of possible annotations in the `annotation_vector` variable.

# %%
import sys
sys.path.append('../')

from defaultconfig import Configuration

class NYTRelevanceAssessmentValidationConfig(Configuration):
    inputColumns = ["index", "bin", "doc_len", "document_id", "document_body", "document_title", "rel", 
                    "topic", "topic_description", "topic_query"]
    outputColumns = ["relevant_snippets"]
    
    annotation_separator = ','
    
    # processing of a closed task
    open_ended_task = True
    annotation_vector = [
        "highly_relevant", "relevant", "not_relevant"
    ]
    
    def processJudgments(self, judgments):
        # change default separator to whitespace to make it work with our file
        for col in self.outputColumns:
            judgments[col] = judgments[col].apply(lambda x: x.replace(' ',','))
        return judgments

config = NYTRelevanceAssessmentValidationConfig()

# %% [markdown]
# ### Pre-process the data and create the annotation vectors

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
from controllers.inputController import processFile
pre_processed_results = processFile(
    root=".", directory="", filename=passages_per_article_ordered_filename,
    config=config
)

# %% [markdown]
# ### Run the metrics

# %%
# run the metrics
from models import Metrics
results_passages_per_article_ordered = Metrics.run(pre_processed_results, config)
# Out:
# INFO:root:1 iterations; max d= 0.963929862186 ; wqs d= 0.587181919515; sqs d= 0.448372346691; rqs d= 0.0
# INFO:root:2 iterations; max d= 0.141790680053 ; wqs d= 0.0529325144308; sqs d= 0.0235939842433; rqs d= 0.0
# INFO:root:3 iterations; max d= 0.0152855104765 ; wqs d= 0.00303080680477; sqs d= 0.0025819075912; rqs d= 0.0
# INFO:root:4 iterations; max d= 0.00525694007633 ; wqs d= 0.000698204437798; sqs d= 0.000747584172969; rqs d= 0.0
# INFO:root:5 iterations; max d= 0.00113924094982 ; wqs d= 0.000186292841998; sqs d= 0.000216744937995; rqs d= 0.0
# INFO:root:6 iterations; max d= 0.000333586475098 ; wqs d= 5.13431393453e-05; sqs d= 4.22248855076e-05; rqs d= 0.0

# %%
results_passages_per_article_ordered["units"].head(5)
# Out:
#               duration  input.bin  input.doc_len  \
# unit
# 1429453518  119.866667          1            196
# 1429453519  103.466667          1            245
# 1429453520   57.466667          1            242
# 1429453521   64.533333          1            237
# 1429453522   32.866667          1            140
#
#                                           input.document_body  \
# unit
# 1429453518  <p>A public commission ruled today that Aum Sh...
# 1429453519  <p>ABC has signed a deal to develop a televisi...
# 1429453520  <p>Japan's peace of mind was shattered anew by...
# 1429453521  <p>USA Networks Interactive, creator of the sc...
# 1429453522  <p>To the Editor:</p> <p>There is ample eviden...
#
#             input.document_id                       input.document_title  \
# unit
# 1429453518            1173003  Japan Puts Gas-Attack Sect Under Scrutiny
# 1429453519             920343            ABC Signs Film Deal On the Cult
# 1429453520             757222           April 16-22; The Scent of Terror
# 1429453521            1209320        SCIFI.com in Venture With Filmmaker
# 1429453522            1667028        Vital at 50: Does Lifestyle Matter?
#
#             input.index  input.rel  input.topic  \
# unit
# 1429453518            1          1          325
# 1429453519            2          1          325
# 1429453520            3          1          325
# 1429453521            4          0          325
# 1429453522            5          0          325
#
#                                       input.topic_description  \
# unit
# 1429453518  Describe a cult by name and identify the cult ...
# 1429453519  Describe a cult by name and identify the cult ...
# 1429453520  Describe a cult by name and identify the cult ...
# 1429453521  Describe a cult by name and identify the cult ...
# 1429453522  Describe a cult by name and identify the cult ...
#
#            input.topic_query  \
# unit
# 1429453518   Cult Lifestyles
# 1429453519   Cult Lifestyles
# 1429453520   Cult Lifestyles
# 1429453521   Cult Lifestyles
# 1429453522   Cult Lifestyles
#
#                                                           job  \
# unit
# 1429453518  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453519  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453520  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453521  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453522  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
#
#                                      output.relevant_snippets  \
# unit
# 1429453518  {u'none': 1, u's3': 10, u's2': 4, u's1': 13, u...
# 1429453519  {u'none': 3, u's3': 3, u's2': 10, u's1': 9, u'...
# 1429453520  {u'none': 1, u's3': 2, u's2': 2, u's1': 3, u's...
# 1429453521  {u'none': 8, u's3': 3, u's1': 7, u's6': 3, u's...
# 1429453522  {u'none': 10, u's8': 2, u's3': 5, u's2': 1, u'...
#
#             output.relevant_snippets.annotations  \
# unit
# 1429453518                                    33
# 1429453519                                    38
# 1429453520                                    49
# 1429453521                                    26
# 1429453522                                    30
#
#             output.relevant_snippets.unique_annotations  worker       uqs  \
# unit
# 1429453518                                            6      15  0.578574
# 1429453519                                            6      15  0.495540
# 1429453520                                            8      15  0.621611
# 1429453521                                            6      15  0.393551
# 1429453522                                            8      15  0.509390
#
#                                         unit_annotation_score  uqs_initial  \
# unit
# 1429453518  {u'none': 0.0736798896324, u's3': 0.7045843948...     0.580890
# 1429453519  {u'none': 0.157598221426, u's3': 0.18877877974...     0.457257
# 1429453520  {u'none': 0.0502536270963, u's3': 0.1351742239...     0.594429
# 1429453521  {u'none': 0.495898619986, u's3': 0.18364153130...     0.403491
# 1429453522  {u'none': 0.687402122175, u's8': 0.13478849964...     0.489593
#
#                                 unit_annotation_score_initial
# unit
# 1429453518  {u'none': 0.0666666666667, u's3': 0.6666666666...
# 1429453519  {u'none': 0.2, u's3': 0.2, u's2': 0.6666666666...
# 1429453520  {u'none': 0.0666666666667, u's3': 0.1333333333...
# 1429453521  {u'none': 0.533333333333, u's3': 0.2, u's1': 0...
# 1429453522  {u'none': 0.666666666667, u's8': 0.13333333333...

# %% [markdown]
# ### Plot the unit quality score (UQS) at the beginning of the process and at the end

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 15, 5

plt.subplot(1, 2, 1)
plt.hist(results_passages_per_article_ordered["units"]["uqs"])
plt.ylim(0, 30)
plt.xlabel("UQS")
plt.ylabel("# Units")

plt.subplot(1, 2, 2)
plt.hist(results_passages_per_article_ordered["units"]["uqs_initial"])
plt.ylim(0, 30)
plt.xlabel("UQS Initial")
plt.ylabel("# Units")
# Out:
# Text(0,0.5,u'# Units')

# %% [markdown]
# ### Plot the change in the unit quality score (UQS) (beginning of the process - end of the process)

# %%
import numpy as np

difference = results_passages_per_article_ordered["units"]["uqs_initial"] - results_passages_per_article_ordered["units"]["uqs"]
difference = np.sort(difference)
plt.plot(np.arange(results_passages_per_article_ordered["units"].shape[0]), difference, 'ro')
plt.axhline(y=0)
plt.xlabel("Unit Index")
plt.ylabel("Change in clarity")
# Out:
# Text(0,0.5,u'Change in clarity')

# %%
sortUQS = results_passages_per_article_ordered["units"].sort(['uqs'], ascending=[1])
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np

plt.rcParams['figure.figsize'] = 15, 5

sortUQS = results_passages_per_article_ordered["units"].sort(['uqs'], ascending=[1])
plt.plot(np.arange(sortUQS.shape[0]), sortUQS["uqs_initial"], 'ro', lw = 1, label = "Initial UQS")
plt.plot(np.arange(sortUQS.shape[0]), sortUQS["uqs"], 'go', lw = 1, label = "Final UQS")

plt.ylabel('Unit Quality Score')
plt.xlabel('Sentence Index')
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """
# Text(0.5,0,u'Sentence Index')

# %% [markdown]
# ### Plot the worker quality score (UQS) at the beginning of the process and at the end

# %% [markdown]
# #### Print the results for the workers in our dataset

# %%
results_passages_per_article_ordered["workers"].head(10)
# Out:
#             duration  output.relevant_snippets.count  job  judgment  unit  \
# worker
# 1924522    39.351852                        3.259259    1        54    54
# 4316379    25.320000                        1.880000    1        25    25
# 6367365    40.111111                        1.555556    1         9     9
# 7348582    87.000000                        5.000000    1         1     1
# 11131207   70.716667                        1.800000    1        60    60
# 15004831  127.113208                        2.188679    1        53    53
# 15193250   57.280702                        7.649123    1        57    57
# 15965551   30.285714                        2.835165    1        91    91
# 18386513   43.500000                        1.666667    1         6     6
# 18666417   59.120000                        2.200000    1        50    50
#
#                wqs  wqs_initial
# worker
# 1924522   0.470201     0.394557
# 4316379   0.512603     0.421016
# 6367365   0.571082     0.508917
# 7348582   0.469018     0.463657
# 11131207  0.469297     0.387304
# 15004831  0.535640     0.461131
# 15193250  0.424947     0.377894
# 15965551  0.443941     0.370366
# 18386513  0.440662     0.381122
# 18666417  0.527529     0.435517

# %%
plt.rcParams['figure.figsize'] = 15, 5

plt.subplot(1, 2, 1)
plt.hist(results_passages_per_article_ordered["workers"]["wqs"])
plt.ylim(0, 25)
plt.xlabel("WQS")
plt.ylabel("# Workers")

plt.subplot(1, 2, 2)
plt.hist(results_passages_per_article_ordered["workers"]["wqs_initial"])
plt.ylim(0, 25)
plt.xlabel("WQS Initial")
plt.ylabel("# Workers")
# Out:
# Text(0,0.5,u'# Workers')

# %% [markdown]
# ### Plot the change in worker qualtity score at the beginning of the process and at the end

# %%
sortWQS = results_passages_per_article_ordered["workers"].sort(['wqs'], ascending=[1])
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.

# %%
plt.rcParams['figure.figsize'] = 15, 5

plt.plot(np.arange(sortWQS.shape[0]), sortWQS["wqs_initial"], 'ro', lw = 1, label = "Initial UQS")
plt.plot(np.arange(sortWQS.shape[0]), sortWQS["wqs"], 'go', lw = 1, label = "Final UQS")

plt.ylabel('Worker Quality Score')
plt.xlabel('Worker Index')
#plt.legend(loc=9, bbox_to_anchor=(0.5, 1.2), ncol=3, prop={'size':12})
# Out:
# Text(0.5,0,u'Worker Index')

# %%
import numpy as np
import pandas as pd

results_passages_per_article_ordered["units"]['max_relevance_score'] = pd.Series(np.random.randn(len(results_passages_per_article_ordered["units"])), index=results_passages_per_article_ordered["units"].index)
results_passages_per_article_ordered["units"]['none_score'] = pd.Series(np.random.randn(len(results_passages_per_article_ordered["units"])), index=results_passages_per_article_ordered["units"].index)

# %%
for i in xrange(0, len(results_passages_per_article_ordered["units"])):
    maxVal = 0.0
    found = False
    for key, value in results_passages_per_article_ordered["units"]["unit_annotation_score"].iloc[i].items():
        if key == "none":
            found = True
            results_passages_per_article_ordered["units"]['none_score'].iloc[i] = value
        else:
            if value > maxVal:
                maxVal = value
    results_passages_per_article_ordered["units"]['max_relevance_score'].iloc[i] = maxVal
    if found == False:
        results_passages_per_article_ordered["units"]['none_score'].iloc[i] = 0.0
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
gt = pd.read_csv("ground_truth_annotation.csv")

results_passages_per_article_ordered["units"]["reviewers_rel"] = pd.Series(np.random.randn(len(results_passages_per_article_ordered["units"].index)), index=results_passages_per_article_ordered["units"].index)
results_passages_per_article_ordered["units"]["reviewers_rel_merged"] = pd.Series(np.random.randn(len(results_passages_per_article_ordered["units"].index)), index=results_passages_per_article_ordered["units"].index)
results_passages_per_article_ordered["units"]["rel_merged"] = pd.Series(np.random.randn(len(results_passages_per_article_ordered["units"].index)), index=results_passages_per_article_ordered["units"].index)

for i in range(0, len(results_passages_per_article_ordered["units"].index)):
    for j in range(0, len(gt.index)):
        if (results_passages_per_article_ordered["units"]["input.topic"].iloc[i] == gt["topic"].iloc[j]) and (results_passages_per_article_ordered["units"]["input.document_id"].iloc[i] == gt["document_id"].iloc[j]):
            results_passages_per_article_ordered["units"]["reviewers_rel"].iloc[i] = gt["reviewers_rel"].iloc[j]
            results_passages_per_article_ordered["units"]["reviewers_rel_merged"].iloc[i] = gt["reviewers_rel_merged"].iloc[j]
            results_passages_per_article_ordered["units"]["rel_merged"].iloc[i] = gt["nist_rel_merged"].iloc[j]

# %%
results_passages_per_article_ordered["units"]
# Out:
#               duration  input.bin  input.doc_len  \
# unit
# 1429453518  119.866667          1            196
# 1429453519  103.466667          1            245
# 1429453520   57.466667          1            242
# 1429453521   64.533333          1            237
# 1429453522   32.866667          1            140
# 1429453523   32.666667          1            173
# 1429453524   49.133333          1            153
# 1429453525   34.066667          1            102
# 1429453526   33.600000          1            172
# 1429453527   42.066667          1             48
# 1429453528   50.333333          1            105
# 1429453529   31.866667          1             51
# 1429453530   50.666667          1             42
# 1429453531   62.600000          1            132
# 1429453532   88.533333          1            480
# 1429453533   48.266667          1             37
# 1429453534   32.600000          1             45
# 1429453535  102.800000          1            261
# 1429453536   58.000000          1            100
# 1429453537   55.800000          1            157
# 1429453538   70.733333          1            193
# 1429453539   44.000000          1            192
# 1429453540   65.933333          1            344
# 1429453541   40.133333          1            148
# 1429453542   45.666667          1            100
# 1429453543   66.066667          1             84
# 1429453544   51.133333          1            100
# 1429453545   60.266667          1             86
# 1429453546   17.400000          1             58
# 1429453547   45.400000          1            105
# ...                ...        ...            ...
# 1429458525  107.666667          2            441
# 1429458526   56.533333          2            394
# 1429458527  109.200000          2            586
# 1429458528   57.600000          2            410
# 1429458529   49.000000          2            464
# 1429458530   88.800000          2            548
# 1429458531   67.400000          2            805
# 1429458532   77.666667          2            847
# 1429458533   61.800000          2            666
# 1429458534   90.066667          2            557
# 1429458535  137.866667          2            755
# 1429458536   73.533333          2            609
# 1429458537   50.333333          2            567
# 1429458538   42.466667          2            357
# 1429458539   69.666667          2            410
# 1429458540   57.200000          2            497
# 1429458541  106.333333          2            428
# 1429458542   52.200000          2            465
# 1429458543  115.133333          2            618
# 1429458544   85.000000          2            579
# 1429458545  150.466667          2            493
# 1429458546   85.666667          2            518
# 1429458547  199.666667          2            444
# 1429458548  112.133333          2            571
# 1429458549   69.533333          2            427
# 1429458550   67.266667          2            558
# 1429458551  163.200000          2            441
# 1429458552   40.800000          2            397
# 1429458553   48.866667          2            402
# 1429458554   59.533333          2            635
#
#                                           input.document_body  \
# unit
# 1429458541          0          379
# 1429458542          0          379
# 1429458543          2          330
# 1429458544          1          330
# 1429458545          1          330
# 1429458546          0          330
# 1429458547          0          330
# 1429458548          0          330
# 1429458549          1          400
# 1429458550          2          400
# 1429458551          1          400
# 1429458552          0          400
# 1429458553          0          400
# 1429458554          0          400
#
#                                       input.topic_description  \
# unit
# 1429453518  Describe a cult by name and identify the cult ...
# 1429453519  Describe a cult by name and identify the cult ...
# 1429453520  Describe a cult by name and identify the cult ...
# 1429453521  Describe a cult by name and identify the cult ...
# 1429453522  Describe a cult by name and identify the cult ...
# 1429453523  Describe a cult by name and identify the cult ...
# 1429453524             Identify incidents of human smuggling.
# 1429453525             Identify incidents of human smuggling.
# 1429453526             Identify incidents of human smuggling.
# 1429453527             Identify incidents of human smuggling.
# 1429453528             Identify incidents of human smuggling.
# 1429453529             Identify incidents of human smuggling.
# 1429453530  Identify documents that discuss opposition to ...
# 1429453531  Identify documents that discuss opposition to ...
# 1429453532  Identify documents that discuss opposition to ...
# 1429453533  Identify documents that discuss opposition to ...
# 1429453534  Identify documents that discuss opposition to ...
# 1429453535  Identify documents that discuss opposition to ...
# 1429453536  Is it hazardous to the health of individuals t...
# 1429453537  Is it hazardous to the health of individuals t...
# 1429453538  Is it hazardous to the health of individuals t...
# 1429453539  Is it hazardous to the health of individuals t...
# 1429453540  Is it hazardous to the health of individuals t...
# 1429453541  Is it hazardous to the health of individuals t...
# 1429453542  What efforts have been made to stabilize the L...
# 1429453543  What efforts have been made to stabilize the L...
# 1429453544  What efforts have been made to stabilize the L...
# 1429453545  What efforts have been made to stabilize the L...
# 1429453546  How much sugar does Cuba export and which coun...
# 1429453547  How much sugar does Cuba export and which coun...
# ...                                                       ...
# 1429458525  How much sugar does Cuba export and which coun...
# 1429458526  How much sugar does Cuba export and which coun...
# 1429458527  How much sugar does Cuba export and which coun...
# 1429458528  How much sugar does Cuba export and which coun...
# 1429458529  How much sugar does Cuba export and which coun...
# 1429458530  How much sugar does Cuba export and which coun...
# 1429458531  Find documents which describe an advantage in ...
# 1429458532  Find documents which describe an advantage in ...
# 1429458533  Find documents which describe an advantage in ...
# 1429458534  Find documents which describe an advantage in ...
# 1429458535  Find documents which describe an advantage in ...
# 1429458536  Find documents which describe an advantage in ...
# 1429458537  Identify documents that discuss mainstreaming ...
# 1429458538  Identify documents that discuss mainstreaming ...
# 1429458539  Identify documents that discuss mainstreaming ...
# 1429458540  Identify documents that discuss mainstreaming ...
# 1429458541  Identify documents that discuss mainstreaming ...
# 1429458542  Identify documents that discuss mainstreaming ...
# 1429458543  This query is looking for examples of cooperat...
# 1429458544  This query is looking for examples of cooperat...
# 1429458545  This query is looking for examples of cooperat...
# 1429458546  This query is looking for examples of cooperat...
# 1429458547  This query is looking for examples of cooperat...
# 1429458548  This query is looking for examples of cooperat...
# 1429458549  What measures are being taken by local South A...
# 1429458550  What measures are being taken by local South A...
# 1429458551  What measures are being taken by local South A...
# 1429458552  What measures are being taken by local South A...
# 1429458553  What measures are being taken by local South A...
# 1429458554  What measures are being taken by local South A...
#
#                         input.topic_query  \
# unit
# 1429453518                Cult Lifestyles
# 1429453519                Cult Lifestyles
# 1429453520                Cult Lifestyles
# 1429453521                Cult Lifestyles
# 1429453522                Cult Lifestyles
# 1429453523                Cult Lifestyles
# 1429453524                human smuggling
# 1429453525                human smuggling
# 1429453526                human smuggling
# 1429453527                human smuggling
# 1429453528                human smuggling
# 1429453529                human smuggling
# 1429453530                euro opposition
# 1429453531                euro opposition
# 1429453532                euro opposition
# 1429453533                euro opposition
# 1429453534                euro opposition
# 1429453535                euro opposition
# 1429453536  Health and Computer Terminals
# 1429453537  Health and Computer Terminals
# 1429453538  Health and Computer Terminals
# 1429453539  Health and Computer Terminals
# 1429453540  Health and Computer Terminals
# 1429453541  Health and Computer Terminals
# 1429453542          Leaning Tower of Pisa
# 1429453543          Leaning Tower of Pisa
# 1429453544          Leaning Tower of Pisa
# 1429453545          Leaning Tower of Pisa
# 1429453546           Cuba, sugar, exports
# 1429453547           Cuba, sugar, exports
# ...                                   ...
# 1429458525           Cuba, sugar, exports
# 1429458526           Cuba, sugar, exports
# 1429458527           Cuba, sugar, exports
# 1429458528           Cuba, sugar, exports
# 1429458529           Cuba, sugar, exports
# 1429458530           Cuba, sugar, exports
# 1429458531    college education advantage
# 1429458532    college education advantage
# 1429458533    college education advantage
# 1429458534    college education advantage
# 1429458535    college education advantage
# 1429458536    college education advantage
# 1429458537                  mainstreaming
# 1429458538                  mainstreaming
# 1429458539                  mainstreaming
# 1429458540                  mainstreaming
# 1429458541                  mainstreaming
# 1429458542                  mainstreaming
# 1429458543          Iran-Iraq Cooperation
# 1429458544          Iran-Iraq Cooperation
# 1429458545          Iran-Iraq Cooperation
# 1429458546          Iran-Iraq Cooperation
# 1429458547          Iran-Iraq Cooperation
# 1429458548          Iran-Iraq Cooperation
# 1429458549             Amazon rain forest
# 1429458550             Amazon rain forest
# 1429458551             Amazon rain forest
# 1429458552             Amazon rain forest
# 1429458553             Amazon rain forest
# 1429458554             Amazon rain forest
#
#                                                           job  \
# unit
# 1429453518  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453519  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453520  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453521  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453522  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453523  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453524  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453525  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453526  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453527  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453528  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453529  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453530  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453531  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453532  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453533  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453534  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453535  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453536  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453537  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453538  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453539  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453540  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453541  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453542  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453543  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453544  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453545  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453546  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429453547  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# ...                                                       ...
# 1429458525  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458526  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458527  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458528  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458529  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458530  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458531  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458532  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458533  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458534  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458535  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458536  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458537  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458538  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458539  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458540  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458541  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458542  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458543  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458544  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458545  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458546  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458547  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458548  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458549  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458550  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458551  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458552  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458553  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
# 1429458554  AnalysisFiles/2P_WithoutHighlight_Passages_Ord...
#
#                                      output.relevant_snippets  \
# unit
# 1429453518  {u'none': 1, u's3': 10, u's2': 4, u's1': 13, u...
# 1429453519  {u'none': 3, u's3': 3, u's2': 10, u's1': 9, u'...
# 1429453520  {u'none': 1, u's3': 2, u's2': 2, u's1': 3, u's...
# 1429453521  {u'none': 8, u's3': 3, u's1': 7, u's6': 3, u's...
# 1429453522  {u'none': 10, u's8': 2, u's3': 5, u's2': 1, u'...
# 1429453523       {u's3': 13, u's2': 10, u'none': 2, u's4': 9}
# 1429453524  {u's3': 8, u's2': 9, u's1': 6, u'none': 2, u's...
# 1429453525       {u's3': 8, u's2': 11, u's1': 14, u'none': 1}
# 1429453526  {u's3': 9, u's2': 15, u's1': 15, u's5': 14, u'...
# 1429453527                            {u'none': 10, u's1': 5}
# 1429453528                            {u'none': 10, u's1': 5}
# 1429453529                             {u's1': 9, u'none': 6}
# 1429453530                            {u'none': 5, u's1': 10}
# 1429453531                            {u'none': 5, u's1': 10}
# 1429453532  {u's9': 11, u's8': 12, u's3': 5, u's2': 5, u's...
# 1429453533                             {u'none': 9, u's1': 6}
# 1429453534                            {u'none': 5, u's1': 10}
# 1429453535  {u'none': 7, u's3': 2, u's2': 7, u's1': 8, u's...
# 1429453536  {u's3': 14, u's2': 10, u'none': 1, u's1': 9, u...
# 1429453537                   {u's2': 7, u'none': 6, u's1': 4}
# 1429453538  {u's3': 11, u's2': 13, u'none': 1, u's5': 1, u...
# 1429453539  {u'none': 9, u's3': 4, u's2': 3, u's1': 4, u's...
# 1429453540  {u'none': 9, u's8': 1, u's3': 6, u's2': 4, u's...
# 1429453541  {u'none': 10, u's3': 5, u's2': 1, u's1': 3, u'...
# 1429453542                            {u'none': 2, u's1': 13}
# 1429453543                                        {u's1': 15}
# 1429453544                  {u's2': 1, u'none': 11, u's1': 3}
# 1429453545                            {u'none': 12, u's1': 3}
# 1429453546                 {u's2': 14, u's1': 13, u'none': 1}
# 1429453547                  {u's2': 12, u'none': 2, u's1': 4}
# ...                                                       ...
# 1429458525  {u's9': 3, u's8': 2, u's3': 2, u's2': 9, u's1'...
# 1429458526  {u's9': 3, u's8': 3, u's3': 2, u's2': 9, u's1'...
# 1429458527  {u's9': 4, u's8': 3, u's3': 7, u's2': 4, u's1'...
# 1429458528  {u's9': 1, u's8': 2, u's3': 2, u's2': 1, u's7'...
# 1429458529  {u's9': 4, u's8': 3, u's3': 6, u's2': 7, u's1'...
# 1429458530  {u's9': 2, u's8': 3, u's3': 4, u's2': 2, u's1'...
# 1429458531  {u's9': 13, u's8': 10, u's3': 6, u's2': 4, u's...
# 1429458532  {u's9': 8, u's8': 10, u's3': 13, u's2': 2, u's...
# 1429458533  {u'none': 8, u's3': 5, u's2': 5, u's1': 5, u's...
# 1429458534  {u's9': 5, u's8': 6, u's3': 10, u's2': 6, u's1...
# 1429458535  {u'none': 5, u's18': 6, u's3': 8, u's2': 6, u'...
# 1429458536  {u's9': 8, u's8': 6, u's3': 5, u's2': 8, u's1'...
# 1429458537  {u's8': 11, u's3': 14, u's2': 8, u's1': 9, u's...
# 1429458538  {u's8': 6, u's3': 12, u's2': 13, u's1': 12, u'...
# 1429458539  {u's9': 12, u's8': 6, u's3': 8, u's2': 13, u's...
# 1429458540  {u's9': 2, u's8': 3, u's3': 3, u's2': 4, u's1'...
# 1429458541  {u'none': 1, u's8': 13, u's3': 9, u's11': 7, u...
# 1429458542  {u's9': 2, u's8': 1, u's3': 8, u's2': 7, u's1'...
# 1429458543  {u's9': 10, u's8': 7, u's3': 14, u's2': 12, u'...
# 1429458544  {u's9': 7, u's8': 5, u's3': 6, u's2': 7, u's1'...
# 1429458545  {u's9': 8, u's8': 8, u's3': 11, u's2': 5, u's1...
# 1429458546  {u's9': 2, u's8': 4, u's3': 6, u's2': 8, u's1'...
# 1429458547  {u's9': 3, u's8': 1, u's3': 3, u's2': 4, u's1'...
# 1429458548  {u's9': 12, u's8': 10, u's3': 8, u's2': 13, u'...
# 1429458549  {u's9': 1, u's8': 9, u's3': 6, u's2': 7, u's1'...
# 1429458550  {u's9': 11, u's8': 12, u's3': 10, u's2': 12, u...
# 1429458551  {u's3': 13, u's2': 13, u's1': 11, u's7': 2, u'...
# 1429458552  {u's3': 14, u's2': 14, u's1': 14, u's5': 13, u...
# 1429458553  {u's9': 11, u's8': 11, u's3': 10, u's1': 1, u'...
# 1429458554  {u's9': 9, u's8': 11, u's3': 8, u's2': 12, u's...
#
#             output.relevant_snippets.annotations  \
# unit
# 1429453518                                    33
# 1429453519                                    38
# 1429453520                                    49
# 1429453521                                    26
# 1429453522                                    30
# 1429453523                                    34
# 1429453524                                    29
# 1429453525                                    34
# 1429453526                                    61
# 1429453527                                    15
# 1429453528                                    15
# 1429453529                                    15
# 1429453530                                    15
# 1429453531                                    15
# 1429453532                                    62
# 1429453533                                    15
# 1429453534                                    15
# 1429453535                                    37
# 1429453536                                    41
# 1429453537                                    17
# 1429453538                                    38
# 1429453539                                    31
# 1429453540                                    50
# 1429453541                                    27
# 1429453542                                    15
# 1429453543                                    15
# 1429453544                                    15
# 1429453545                                    15
# 1429453546                                    28
# 1429453547                                    18
# ...                                          ...
# 1429458525                                    38
# 1429458526                                    60
# 1429458527                                    67
# 1429458528                                    28
# 1429458529                                    60
# 1429458530                                    45
# 1429458531                                    85
# 1429458532                                   103
# 1429458533                                    40
# 1429458534                                   104
# 1429458535                                   111
# 1429458536                                    62
# 1429458537                                    84
# 1429458538                                    89
# 1429458539                                   102
# 1429458540                                    50
# 1429458541                                    67
# 1429458542                                    75
# 1429458543                                   157
# 1429458544                                    85
# 1429458545                                    86
# 1429458546                                    68
# 1429458547                                    43
# 1429458548                                   126
# 1429458549                                    64
# 1429458550                                   146
# 1429458551                                    57
# 1429458552                                    67
# 1429458553                                    80
# 1429458554                                    80
#
#             output.relevant_snippets.unique_annotations  worker       uqs  \
# unit
# 1429453518                                            6      15  0.578574
# 1429453519                                            6      15  0.495540
# 1429453520                                            8      15  0.621611
# 1429453521                                            6      15  0.393551
# 1429453522                                            8      15  0.509390
# 1429453523                                            4      15  0.681071
# 1429453524                                            5      15  0.437912
# 1429453525                                            4      15  0.760753
# 1429453526                                            5      15  0.863503
# 1429453527                                            2      15  0.568252
# 1429453528                                            2      15  0.514968
# 1429453529                                            2      15  0.487149
# 1429453530                                            2      15  0.513947
# 1429453531                                            2      15  0.523796
# 1429453532                                           10      15  0.582848
# 1429453533                                            2      15  0.487071
# 1429453534                                            2      15  0.518685
# 1429453535                                            7      15  0.389018
# 1429453536                                            5      15  0.691259
# 1429453537                                            3      15  0.369639
# 1429453538                                            5      15  0.741236
# 1429453519  {u'none': 0.2, u's3': 0.2, u's2': 0.6666666666...
# 1429453520  {u'none': 0.0666666666667, u's3': 0.1333333333...
# 1429453521  {u'none': 0.533333333333, u's3': 0.2, u's1': 0...
# 1429453522  {u'none': 0.666666666667, u's8': 0.13333333333...
# 1429453523  {u's3': 0.866666666667, u's2': 0.666666666667,...
# 1429453524  {u's3': 0.533333333333, u's2': 0.6, u's1': 0.4...
# 1429453525  {u's3': 0.533333333333, u's2': 0.733333333333,...
# 1429453526  {u's3': 0.6, u's2': 1.0, u's1': 1.0, u's5': 0....
# 1429453527   {u'none': 0.666666666667, u's1': 0.333333333333}
# 1429453528   {u'none': 0.666666666667, u's1': 0.333333333333}
# 1429453529                         {u's1': 0.6, u'none': 0.4}
# 1429453530   {u'none': 0.333333333333, u's1': 0.666666666667}
# 1429453531   {u'none': 0.333333333333, u's1': 0.666666666667}
# 1429453532  {u's9': 0.733333333333, u's8': 0.8, u's3': 0.3...
# 1429453533                         {u'none': 0.6, u's1': 0.4}
# 1429453534   {u'none': 0.333333333333, u's1': 0.666666666667}
# 1429453535  {u'none': 0.466666666667, u's3': 0.13333333333...
# 1429453536  {u's3': 0.933333333333, u's2': 0.666666666667,...
# 1429453537  {u's2': 0.466666666667, u'none': 0.4, u's1': 0...
# 1429453538  {u's3': 0.733333333333, u's2': 0.866666666667,...
# 1429453539  {u'none': 0.6, u's3': 0.266666666667, u's2': 0...
# 1429453540  {u'none': 0.6, u's8': 0.0666666666667, u's3': ...
# 1429453541  {u'none': 0.666666666667, u's3': 0.33333333333...
# 1429453542   {u'none': 0.133333333333, u's1': 0.866666666667}
# 1429453543                                       {u's1': 1.0}
# 1429453544  {u's2': 0.0666666666667, u'none': 0.7333333333...
# 1429453545                         {u'none': 0.8, u's1': 0.2}
# 1429453546  {u's2': 0.933333333333, u's1': 0.866666666667,...
# 1429453547  {u's2': 0.8, u'none': 0.133333333333, u's1': 0...
# ...                                                       ...
# 1429458525  {u's9': 0.2, u's8': 0.133333333333, u's3': 0.1...
# 1429458526  {u's9': 0.2, u's8': 0.2, u's3': 0.133333333333...
# 1429458527  {u's9': 0.266666666667, u's8': 0.2, u's3': 0.4...
# 1429458528  {u's9': 0.0666666666667, u's8': 0.133333333333...
# 1429458529  {u's9': 0.266666666667, u's8': 0.2, u's3': 0.4...
# 1429458530  {u's9': 0.133333333333, u's8': 0.2, u's3': 0.2...
# 1429458531  {u's9': 0.866666666667, u's8': 0.666666666667,...
# 1429458532  {u's9': 0.533333333333, u's8': 0.666666666667,...
# 1429458533  {u'none': 0.533333333333, u's3': 0.33333333333...
# 1429458534  {u's9': 0.333333333333, u's8': 0.4, u's3': 0.6...
# 1429458535  {u'none': 0.333333333333, u's18': 0.4, u's3': ...
# 1429458536  {u's9': 0.533333333333, u's8': 0.4, u's3': 0.3...
# 1429458537  {u's8': 0.733333333333, u's3': 0.933333333333,...
# 1429458538  {u's8': 0.4, u's3': 0.8, u's2': 0.866666666667...
# 1429458539  {u's9': 0.8, u's8': 0.4, u's3': 0.533333333333...
# 1429458541             0.870221    0.068170            1.0
# 1429458542             0.909998    0.037933            1.0
# 1429458543             0.940480    0.000000            2.0
# 1429458544             0.645094    0.239001            1.0
# 1429458545             0.796638    0.038231            1.0
# 1429458546             0.623629    0.299732            0.0
# 1429458547             0.333727    0.548340            0.0
# 1429458548             0.888817    0.000000            1.0
# 1429458549             1.000000    0.000000            2.0
# 1429458550             0.954196    0.000000            1.0
# 1429458551             0.869582    0.000000            2.0
# 1429458552             0.954196    0.000000            2.0
# 1429458553             0.920588    0.035174            1.0
# 1429458554             0.809270    0.000000            1.0
#
#             reviewers_rel_merged  rel_merged
# unit
# 1429453518                   1.0         1.0
# 1429453519                   1.0         1.0
# 1429453520                   1.0         1.0
# 1429453521                   0.0         0.0
# 1429453522                   0.0         0.0
# 1429453523                   1.0         0.0
# 1429453524                   1.0         1.0
# 1429453525                   1.0         1.0
# 1429453526                   1.0         1.0
# 1429453527                   0.0         0.0
# 1429453528                   0.0         0.0
# 1429453529                   0.0         0.0
# 1429453530                   0.0         1.0
# 1429453531                   0.0         1.0
# 1429453532                   1.0         1.0
# 1429453533                   0.0         0.0
# 1429453534                   0.0         0.0
# 1429453535                   0.0         0.0
# 1429453536                   1.0         1.0
# 1429453537                   1.0         1.0
# 1429453538                   1.0         1.0
# 1429453539                   0.0         0.0
# 1429453540                   0.0         0.0
# 1429453541                   0.0         0.0
# 1429453542                   1.0         1.0
# 1429453543                   1.0         1.0
# 1429453544                   0.0         0.0
# 1429453545                   0.0         0.0
# 1429453546                   1.0         1.0
# 1429453547                   1.0         1.0
# ...                          ...         ...
# 1429458525                   1.0         1.0
# 1429458526                   1.0         1.0
# 1429458527                   1.0         1.0
# 1429458528                   0.0         0.0
# 1429458529                   0.0         0.0
# 1429458530                   1.0         0.0
# 1429458531                   1.0         1.0
# 1429458532                   1.0         1.0
# 1429458533                   0.0         0.0
# 1429458534                   0.0         0.0
# 1429458535                   1.0         0.0
# 1429458536                   0.0         0.0
# 1429458537                   1.0         1.0
# 1429458538                   1.0         1.0
# 1429458539                   1.0         1.0
# 1429458540                   0.0         0.0
# 1429458541                   1.0         0.0
# 1429458542                   1.0         0.0
# 1429458543                   1.0         1.0
# 1429458544                   1.0         1.0
# 1429458545                   1.0         1.0
# 1429458546                   0.0         0.0
# 1429458547                   0.0         0.0
# 1429458548                   1.0         0.0
# 1429458549                   1.0         1.0
# 1429458550                   1.0         1.0
# 1429458551                   1.0         1.0
# 1429458552                   1.0         0.0
# 1429458553                   1.0         0.0
# 1429458554                   1.0         0.0
#
# [116 rows x 25 columns]

# %%
results_passages_per_article_ordered["units"].to_csv("ResultFiles/2P_WithoutHighlight_Passages_Ordered/units_withoutHighlight_15workers_2p_passages.csv", index=False)

# %% [markdown]
# ## Print the files with results

# %%
results_passages_per_article_ordered["units"].to_csv("ResultFiles/2P_WithoutHighlight_Passages_Ordered/units_withoutHighlight_15workers_2p_passages.csv")

# %%
results_passages_per_article_ordered["workers"].to_csv("ResultFiles/2P_WithoutHighlight_Passages_Ordered/workers_withoutHighlight_15workers_2p_passages.csv")
