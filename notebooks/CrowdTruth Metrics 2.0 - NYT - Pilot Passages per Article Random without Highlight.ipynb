# %% [markdown]
# # CrowdTruth metrics 2.0 documentation
#
# Let:
#
# * $workers(u):$ all workers that annotate media unit $u$;
# * $units(i):$ all input media units annotated by worker $i$;
# * $WorkVec(i, u):$ annotations of worker $i$ on media unit $u$ as a binary vector;
# * $MediaUnitVec(s) = \sum_{i \in workers(s)} WorkVec(i,s)$, where $s$ is an input media unit.
#
# ## Media Unit Quality Score (UQS)
#
# The unit quality score $UQS(u)$ is computed as the average cosine similarity between all worker vectors for a given input media unit $u$, weighted by the worker quality ($WQS$) and annotation quality ($AQS$). The goal is to capture the degree of agreement in annotating the media unit. Through the weighted average, workers and annotations with lower quality will have less of an impact on the final score.
#
# $$ UQS(u) = \frac{\sum_{i, j \in workers(u)} Wcos(WorkVec(i,u), WorkVec(j,u)) \; WQS(i) \; WQS(j)}{\sum_{i, j \in workers(u)} WQS(i) \; WQS(j)}, \; i \neq j.$$
#
#
# ### Weighted Cosine
#
# To weigh the metrics with the annotation quality, we compute $Wcos$, the weighted version of the cosine similarity. This metric is only applicable to closed tasks, where annotation quality can be calculated across media units. For open-ended tasks, we consider annotation quality equal to 1 and calculate the regular cosine similarity.
#
# $$ Wcos(vec_1, vec_2) = \frac{\sum_{a} vec_1(a) \; vec_2(a) \; AQS(a)}{\sqrt{(\sum_{a} vec_1^2(a) \; AQS(a)) \; (\sum_{a} vec_2^2(a) \; AQS(a))}} .$$
#
#
# ## Worker Quality Score (WQS)
#
# The worker quality score $WQS(i)$ for a given worker $i$ is the product of 2 separate metrics - the worker-worker agreement $WWA(i)$ and the worker-media unit agreement $WUA(i)$.
#
# $$ WQS(i) = WUA(i) \; WWA(i) .$$
#
# ### Worker-Media Unit Agreement
#
# The worker-media unit agreement $WUA(i)$ is the average cosine distance between the annotations of a worker $i$ and all annotations for the media units they have worked on, weighted by the media unit and annotation quality. It calculates how much a worker disagrees with the crowd on a media unit basis. Through the weighted average, media units and anntation with lower quality will have less of an impact on the final score.
#
# $$ WSA(i) = \frac{\sum_{u \in units(i)} Wcos(WorkVec(i,u), MediaUnitVec(u) - WorkVec(i, u)) \; UQS(u)}{\sum_{u \in units(i)} UQS(u)} .$$
#
# ### Worker-Worker Agreement
#
# The worker-worker agreement $WWA(i)$ is the average cosine distance between the annotations of a worker $i$ and all other workers that have worked on the same media units as worker $i$, weighted by the worker and annotation qualities. The metric gives an indication as to whether there are consisently like-minded workers. This is useful for identifying communities of thought. Through the weighted average, workers and annotations with lower quality will have less of an impact on the final score of the given worker.
#
# $$ WWA(i) = \frac{ \sum_{j \in workers(u \in units(i))} Wcos(WorkVec(i, u), WorkVec(j, u)) \; WQS(j) \; UQS(u) }{ \sum_{j \in workers(s \in units(i))} WQS(j) \; UQS(u) }, \; i \neq j .$$
#
#
# ## Annotation Quality Score (AQS)
#
# The annotation quality score $AQS(a)$ calculates the agreement of selecting an annotation $a$, over all the media units it appears in. Therefore, it is only applicable to closed tasks, where the same annotation set is used for all input media units. It is based on $P_a(i | j)$, the probability that if a worker $j$ annotates $a$ in a media unit, worker $i$ will also annotate it.
#
# $$ P_a(i | j) = \frac{ \sum_{u \in units(i) \cap units(j) } UQS(u) \; WorkVec(i, s)(r) \; WorkVec(j, s)(r) }{ \sum_{u \in units(i) \cap units(j) } UQS(u) \; WorkVec(j, u)(r) } . $$
#
# $AQS(a)$ is the weighted average of $P_a(i | j)$ for all possible pairs of workers. Through the weighted average, input media units and workers with lower quality will have less of an impact on the final score of the annotation.
#
# $$ AQS(a) = \frac{ \sum_{i,j} WQS(i) \; WQS(j) \; P_a(i | j) }{ \sum_{i,j} WQS(i) \; WQS(j) }, i \neq j . $$
#
#
# ## Media Unit-Annotation Score (UAS)
#
# The media unit - annotation score $UAS(u, a)$ calculates the likelihood that annotation $a$ is expressed in input media unit $u$. It is the ratio of the number of workers that picked annotation $u$ over all workers that annotated the unit, weighted by the worker quality.
#
# $$ UAS(u, a) = \frac{ \sum_{i \in workers(u)} WorkVec(i,u)(a) \; WQS(i) }{ \sum_{i \in workers(u)} WQS(i) }. $$

# %% [markdown]
# # How to run the metrics

# %%
# Read data

import pandas as pd

pd.set_option('display.max_columns', None)
passages_per_article_random_filename = "AnalysisFiles/2P_WithoutHighlight_Passages_Random/passages_per_article_random.csv"
passages_per_article_random_dataset = pd.read_csv(passages_per_article_random_filename)

passages_per_article_random_dataset.head(10)
# Out:
#      _unit_id          _created_at         _id          _started_at _tainted  \
# 0  1429458914  10/29/2017 00:47:23  2967354241  10/29/2017 00:46:20    False
# 1  1429458914  10/29/2017 02:15:41  2967472140  10/29/2017 02:12:16    False
# 2  1429458914  10/29/2017 02:15:42  2967472141  10/29/2017 02:15:16    False
# 3  1429458914  10/29/2017 02:51:50  2967516376  10/29/2017 02:50:51    False
# 4  1429458914  10/29/2017 05:13:56  2967652549  10/29/2017 05:10:21    False
# 5  1429458914  10/29/2017 06:59:10  2967730167  10/29/2017 06:58:49    False
# 6  1429458914  10/29/2017 09:51:25  2967828164  10/29/2017 09:50:57    False
# 7  1429458914  10/29/2017 11:43:03  2967909752  10/29/2017 11:42:15    False
# 8  1429458914  10/29/2017 12:14:26  2967938884  10/29/2017 12:13:13    False
# 9  1429458914  10/29/2017 15:30:00  2968221893  10/29/2017 15:28:54    False
#
#          _channel  _trust  _worker_id _country _region             _city  \
# 0      fusioncash       1    41545007      USA      NV         Las Vegas
# 1         prodege       1    38548574      USA      ME           Caribou
# 2  gifthunterclub       1    43999669      USA      NY          New York
# 3        gifthulk       1    18666417      USA      PA         Meadville
# 4         prodege       1    23919502      AUS       5          Adelaide
# 5      bitcoinget       1    43891892      USA      NJ      North Bergen
# 6         prodege       1    39884878      GBR      M8        Bermondsey
# 7         prodege       1    32142063      GBR      G5        Canterbury
# 8     tremorgames       1    32655637      CAN      ON         Thornhill
# 9       clixsense       1    43984981      USA      CO  Colorado Springs
#
#               _ip  hiddeninput  highlighted1  highlighted2  highlighted3  \
# 0    24.120.53.14          NaN           NaN           NaN           NaN
# 1    98.13.82.121          NaN           NaN           NaN           NaN
# 2  165.227.57.139          NaN           NaN           NaN           NaN
# 3   24.239.63.206          NaN           NaN           NaN           NaN
# 4   49.178.13.186          NaN           NaN           NaN           NaN
# 5  192.241.129.19          NaN           NaN           NaN           NaN
# 6    2.216.48.186          NaN           NaN           NaN           NaN
# 7    5.81.182.239          NaN           NaN           NaN           NaN
# 8  135.23.217.131          NaN           NaN           NaN           NaN
# 9  75.163.199.102          NaN           NaN           NaN           NaN
#
#    highlighted4  highlighted5   notrelevant_snippets  relevance_s1  \
# 0           NaN           NaN            ["s5","s4"]           NaN
# 1           NaN           NaN       ["s4","s5","s2"]           NaN
# 2           NaN           NaN                     []           NaN
# 3           NaN           NaN       ["s5","s2","s4"]           NaN
# 4           NaN           NaN  ["s2","s3","s5","s4"]           NaN
# 5           NaN           NaN  ["s2","s3","s4","s5"]           NaN
# 6           NaN           NaN       ["s4","s5","s2"]           NaN
# 7           NaN           NaN       ["s5","s2","s4"]           NaN
# 8           NaN           NaN            ["s2","s5"]           NaN
# 9           NaN           NaN            ["s4","s5"]           NaN
#
#    relevance_s2  relevance_s3  relevance_s4  relevance_s5 relevant_snippets  \
# 0           NaN           NaN           NaN           NaN          s2,s1,s3
# 1           NaN           NaN           NaN           NaN             s3,s1
# 2           NaN           NaN           NaN           NaN    s2,s3,s4,s1,s5
# 3           NaN           NaN           NaN           NaN             s1,s3
# 4           NaN           NaN           NaN           NaN                s1
# 5           NaN           NaN           NaN           NaN                s1
# 6           NaN           NaN           NaN           NaN             s1,s3
# 7           NaN           NaN           NaN           NaN             s1,s3
# 8           NaN           NaN           NaN           NaN          s3,s1,s4
# 9           NaN           NaN           NaN           NaN          s2,s1,s3
#
#    bin  doc_len                                      document_body  \
# 0    1      196  <p>A public commission ruled today that Aum Sh...
# 1    1      196  <p>A public commission ruled today that Aum Sh...
# 2    1      196  <p>A public commission ruled today that Aum Sh...
# 3    1      196  <p>A public commission ruled today that Aum Sh...
# 4    1      196  <p>A public commission ruled today that Aum Sh...
# 5    1      196  <p>A public commission ruled today that Aum Sh...
# 6    1      196  <p>A public commission ruled today that Aum Sh...
# 7    1      196  <p>A public commission ruled today that Aum Sh...
# 8    1      196  <p>A public commission ruled today that Aum Sh...
# 9    1      196  <p>A public commission ruled today that Aum Sh...
#
#    document_id                             document_title  hiddeninput_gold  \
# 0      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 1      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 2      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 3      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 4      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 5      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 6      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 7      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 8      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
# 9      1173003  Japan Puts Gas-Attack Sect Under Scrutiny               NaN
#
#    highlighted1_gold  highlighted2_gold  highlighted3_gold  highlighted4_gold  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7                NaN                NaN                NaN                NaN
# 8                NaN                NaN                NaN                NaN
# 9                NaN                NaN                NaN                NaN
#
#    highlighted5_gold  index  notrelevant_snippets_gold  rel  \
# 0                NaN      1                        NaN    1
# 1                NaN      1                        NaN    1
# 2                NaN      1                        NaN    1
# 3                NaN      1                        NaN    1
# 4                NaN      1                        NaN    1
# 5                NaN      1                        NaN    1
# 6                NaN      1                        NaN    1
# 7                NaN      1                        NaN    1
# 8                NaN      1                        NaN    1
# 9                NaN      1                        NaN    1
#
#    relevance_s1_gold  relevance_s2_gold  relevance_s3_gold  relevance_s4_gold  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7                NaN                NaN                NaN                NaN
# 8                NaN                NaN                NaN                NaN
# 9                NaN                NaN                NaN                NaN
#
#    relevance_s5_gold  relevant_snippets_gold  \
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# 5                NaN                     NaN
# 6                NaN                     NaN
# 7                NaN                     NaN
# 8                NaN                     NaN
# 9                NaN                     NaN
#
#                                    sentence0  \
# 0  Japan Puts Gas-Attack Sect Under Scrutiny
# 1  Japan Puts Gas-Attack Sect Under Scrutiny
# 2  Japan Puts Gas-Attack Sect Under Scrutiny
# 3  Japan Puts Gas-Attack Sect Under Scrutiny
# 4  Japan Puts Gas-Attack Sect Under Scrutiny
# 5  Japan Puts Gas-Attack Sect Under Scrutiny
# 6  Japan Puts Gas-Attack Sect Under Scrutiny
# 7  Japan Puts Gas-Attack Sect Under Scrutiny
# 8  Japan Puts Gas-Attack Sect Under Scrutiny
# 9  Japan Puts Gas-Attack Sect Under Scrutiny
#
#                                            sentence1 sentence10 sentence11  \
# 0  A public commission ruled today that Aum Shinr...        NaN        NaN
# 1  A public commission ruled today that Aum Shinr...        NaN        NaN
# 2  A public commission ruled today that Aum Shinr...        NaN        NaN
# 3  A public commission ruled today that Aum Shinr...        NaN        NaN
# 4  A public commission ruled today that Aum Shinr...        NaN        NaN
# 5  A public commission ruled today that Aum Shinr...        NaN        NaN
# 6  A public commission ruled today that Aum Shinr...        NaN        NaN
# 7  A public commission ruled today that Aum Shinr...        NaN        NaN
# 8  A public commission ruled today that Aum Shinr...        NaN        NaN
# 9  A public commission ruled today that Aum Shinr...        NaN        NaN
#
#   sentence12 sentence13 sentence14 sentence15 sentence16 sentence17  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
# 5        NaN        NaN        NaN        NaN        NaN        NaN
# 6        NaN        NaN        NaN        NaN        NaN        NaN
# 7        NaN        NaN        NaN        NaN        NaN        NaN
# 8        NaN        NaN        NaN        NaN        NaN        NaN
# 9        NaN        NaN        NaN        NaN        NaN        NaN
#
#   sentence18 sentence19                                          sentence2  \
# 0        NaN        NaN  The Public Security Examination Commission, wh...
# 1        NaN        NaN  The Public Security Examination Commission, wh...
# 2        NaN        NaN  The Public Security Examination Commission, wh...
# 3        NaN        NaN  The Public Security Examination Commission, wh...
# 4        NaN        NaN  The Public Security Examination Commission, wh...
# 5        NaN        NaN  The Public Security Examination Commission, wh...
# 6        NaN        NaN  The Public Security Examination Commission, wh...
# 7        NaN        NaN  The Public Security Examination Commission, wh...
# 8        NaN        NaN  The Public Security Examination Commission, wh...
# 9        NaN        NaN  The Public Security Examination Commission, wh...
#
#   sentence20                                          sentence3  \
# 0        NaN  Under the surveillance law -- specifically dir...
# 1        NaN  Under the surveillance law -- specifically dir...
# 2        NaN  Under the surveillance law -- specifically dir...
# 3        NaN  Under the surveillance law -- specifically dir...
# 4        NaN  Under the surveillance law -- specifically dir...
# 5        NaN  Under the surveillance law -- specifically dir...
# 6        NaN  Under the surveillance law -- specifically dir...
# 7        NaN  Under the surveillance law -- specifically dir...
# 8        NaN  Under the surveillance law -- specifically dir...
# 9        NaN  Under the surveillance law -- specifically dir...
#
#                                            sentence4  \
# 0  Beginning on Tuesday, when the commission's de...
# 1  Beginning on Tuesday, when the commission's de...
# 2  Beginning on Tuesday, when the commission's de...
# 3  Beginning on Tuesday, when the commission's de...
# 4  Beginning on Tuesday, when the commission's de...
# 5  Beginning on Tuesday, when the commission's de...
# 6  Beginning on Tuesday, when the commission's de...
# 7  Beginning on Tuesday, when the commission's de...
# 8  Beginning on Tuesday, when the commission's de...
# 9  Beginning on Tuesday, when the commission's de...
#
#                                            sentence5 sentence6 sentence7  \
# 0  Human rights advocates and civil libertarians ...       NaN       NaN
# 1  Human rights advocates and civil libertarians ...       NaN       NaN
# 2  Human rights advocates and civil libertarians ...       NaN       NaN
# 3  Human rights advocates and civil libertarians ...       NaN       NaN
# 4  Human rights advocates and civil libertarians ...       NaN       NaN
# 5  Human rights advocates and civil libertarians ...       NaN       NaN
# 6  Human rights advocates and civil libertarians ...       NaN       NaN
# 7  Human rights advocates and civil libertarians ...       NaN       NaN
# 8  Human rights advocates and civil libertarians ...       NaN       NaN
# 9  Human rights advocates and civil libertarians ...       NaN       NaN
#
#   sentence8 sentence9  topic  \
# 0       NaN       NaN    325
# 1       NaN       NaN    325
# 2       NaN       NaN    325
# 3       NaN       NaN    325
# 4       NaN       NaN    325
# 5       NaN       NaN    325
# 6       NaN       NaN    325
# 7       NaN       NaN    325
# 8       NaN       NaN    325
# 9       NaN       NaN    325
#
#                                    topic_description      topic_query
# 0  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 1  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 2  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 3  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 4  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 5  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 6  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 7  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 8  Describe a cult by name and identify the cult ...  Cult Lifestyles
# 9  Describe a cult by name and identify the cult ...  Cult Lifestyles

# %% [markdown]
# ### Creating a class that inherits from `Configuration` lets us define how the input file will be processed:
#
# * `inputColumns`: list of input columns from the .csv file, the input that the workers were shown
# * `outputColumns`: list of output columns with the answers from the workers
# * `processJudgments`: function that defines how the worker judgments wil be processed; default separator for judgments is ','
#
# To build the annotation vector, we also need to specify whether this is an **open-ended** or **closed** task, using the `open_ended_task` variable.
#
# * **open-ended task** means that the annotation space is not known, and workers can freely provide all the choices that apply (e.g. in sound tagging, the workers are provided with a text box to enter all tags they can think of)
# * **closed task** means that the annotations that can occur in the data are already known, and the workers are asked to validate their existence (e.g. for medical relation extraction, the workers pick from a pre-defined multiple-choice set of relations)
#
# If the task we are processing is **closed**, then we also need to provide the list of possible annotations in the `annotation_vector` variable.

# %%
import sys
sys.path.append('../')

from defaultconfig import Configuration

class NYTRelevanceAssessmentValidationConfig(Configuration):
    inputColumns = ["index", "bin", "doc_len", "document_id", "document_body", "document_title", "rel", 
                    "topic", "topic_description", "topic_query"]
    outputColumns = ["relevant_snippets"]
    
    annotation_separator = ','
    
    # processing of a closed task
    open_ended_task = True
    annotation_vector = [
        "highly_relevant", "relevant", "not_relevant"
    ]
    
    def processJudgments(self, judgments):
        # change default separator to whitespace to make it work with our file
        for col in self.outputColumns:
            judgments[col] = judgments[col].apply(lambda x: x.replace(' ',','))
        return judgments

config = NYTRelevanceAssessmentValidationConfig()

# %% [markdown]
# ### Pre-process the data and create the annotation vectors

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
from controllers.inputController import processFile
pre_processed_results = processFile(
    root=".", directory="", filename=passages_per_article_random_filename,
    config=config
)

# %% [markdown]
# ### Run the metrics

# %%
# run the metrics
from models import Metrics
results_passages_per_article_random = Metrics.run(pre_processed_results, config)
# Out:
# INFO:root:1 iterations; max d= 0.976514430385 ; wqs d= 0.543419086973; sqs d= 0.458320786266; rqs d= 0.0
# INFO:root:2 iterations; max d= 0.141626767492 ; wqs d= 0.0650544527968; sqs d= 0.0341202836312; rqs d= 0.0
# INFO:root:3 iterations; max d= 0.0175808893406 ; wqs d= 0.00374905397558; sqs d= 0.00329466747564; rqs d= 0.0
# INFO:root:4 iterations; max d= 0.00436370326929 ; wqs d= 0.00101040935085; sqs d= 0.00117354287779; rqs d= 0.0
# INFO:root:5 iterations; max d= 0.00105219373174 ; wqs d= 0.000214981824984; sqs d= 0.000280535177376; rqs d= 0.0
# INFO:root:6 iterations; max d= 0.000299555776463 ; wqs d= 7.46733932665e-05; sqs d= 5.86098460375e-05; rqs d= 0.0

# %%
results_passages_per_article_random["units"].head(5)
# Out:
#               duration  input.bin  input.doc_len  \
# unit
# 1429458914   96.200000          1            196
# 1429458915  138.466667          1            245
# 1429458916   99.600000          1            242
# 1429458918   77.333333          1            237
# 1429458919   51.800000          1            140
#
#                                           input.document_body  \
# unit
# 1429458914  <p>A public commission ruled today that Aum Sh...
# 1429458915  <p>ABC has signed a deal to develop a televisi...
# 1429458916  <p>Japan's peace of mind was shattered anew by...
# 1429458918  <p>USA Networks Interactive, creator of the sc...
# 1429458919  <p>To the Editor:</p> <p>There is ample eviden...
#
#             input.document_id                       input.document_title  \
# unit
# 1429458914            1173003  Japan Puts Gas-Attack Sect Under Scrutiny
# 1429458915             920343            ABC Signs Film Deal On the Cult
# 1429458916             757222           April 16-22; The Scent of Terror
# 1429458918            1209320        SCIFI.com in Venture With Filmmaker
# 1429458919            1667028        Vital at 50: Does Lifestyle Matter?
#
#             input.index  input.rel  input.topic  \
# unit
# 1429458914            1          1          325
# 1429458915            2          1          325
# 1429458916            3          1          325
# 1429458918            4          0          325
# 1429458919            5          0          325
#
#                                       input.topic_description  \
# unit
# 1429458914  Describe a cult by name and identify the cult ...
# 1429458915  Describe a cult by name and identify the cult ...
# 1429458916  Describe a cult by name and identify the cult ...
# 1429458918  Describe a cult by name and identify the cult ...
# 1429458919  Describe a cult by name and identify the cult ...
#
#            input.topic_query  \
# unit
# 1429458914   Cult Lifestyles
# 1429458915   Cult Lifestyles
# 1429458916   Cult Lifestyles
# 1429458918   Cult Lifestyles
# 1429458919   Cult Lifestyles
#
#                                                           job  \
# unit
# 1429458914  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458915  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458916  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458918  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458919  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
#
#                                      output.relevant_snippets  \
# unit
# 1429458914  {u's3': 13, u's2': 5, u's1': 15, u's5': 2, u's...
# 1429458915  {u'none': 1, u's3': 2, u's2': 11, u's1': 13, u...
# 1429458916  {u'none': 1, u's3': 5, u's2': 4, u's1': 3, u's...
# 1429458918  {u'none': 14, u's3': 1, u's1': 1, u's6': 1, u'...
# 1429458919  {u'none': 10, u's8': 3, u's3': 3, u's2': 4, u'...
#
#             output.relevant_snippets.annotations  \
# unit
# 1429458914                                    39
# 1429458915                                    36
# 1429458916                                    50
# 1429458918                                    19
# 1429458919                                    31
#
#             output.relevant_snippets.unique_annotations  worker       uqs  \
# unit
# 1429458914                                            5      15  0.787503
# 1429458915                                            6      15  0.664548
# 1429458916                                            8      15  0.490894
# 1429458918                                            6      15  0.904753
# 1429458919                                            9      15  0.531708
#
#                                         unit_annotation_score  uqs_initial  \
# unit
# 1429458914  {u's3': 0.88207358729, u's2': 0.320763811574, ...     0.775913
# 1429458915  {u'none': 0.0329385189467, u's3': 0.1085889609...     0.623751
# 1429458916  {u'none': 0.0789884822062, u's3': 0.2833616421...     0.473937
# 1429458918  {u'none': 0.953698996643, u's3': 0.04630100335...     0.866667
# 1429458919  {u'none': 0.7159855514, u's8': 0.159258034982,...     0.478242
#
#                                 unit_annotation_score_initial
# unit
# 1429458914  {u's3': 0.866666666667, u's2': 0.333333333333,...
# 1429458915  {u'none': 0.0666666666667, u's3': 0.1333333333...
# 1429458916  {u'none': 0.0666666666667, u's3': 0.3333333333...
# 1429458918  {u'none': 0.933333333333, u's3': 0.06666666666...
# 1429458919  {u'none': 0.666666666667, u's8': 0.2, u's3': 0...

# %% [markdown]
# ### Plot the unit quality score (UQS) at the beginning of the process and at the end

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 15, 5

plt.subplot(1, 2, 1)
plt.hist(results_passages_per_article_random["units"]["uqs"])
plt.ylim(0, 30)
plt.xlabel("UQS")
plt.ylabel("# Units")

plt.subplot(1, 2, 2)
plt.hist(results_passages_per_article_random["units"]["uqs_initial"])
plt.ylim(0, 30)
plt.xlabel("UQS Initial")
plt.ylabel("# Units")
# Out:
# Text(0,0.5,u'# Units')

# %% [markdown]
# ### Plot the change in the unit quality score (UQS) (beginning of the process - end of the process)

# %%
import numpy as np

difference = results_passages_per_article_random["units"]["uqs_initial"] - results_passages_per_article_random["units"]["uqs"]
difference = np.sort(difference)
plt.plot(np.arange(results_passages_per_article_random["units"].shape[0]), difference, 'ro')
plt.axhline(y=0)
plt.xlabel("Unit Index")
plt.ylabel("Change in clarity")
# Out:
# Text(0,0.5,u'Change in clarity')

# %%
sortUQS = results_passages_per_article_random["units"].sort(['uqs'], ascending=[1])
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np

plt.rcParams['figure.figsize'] = 15, 5

plt.plot(np.arange(sortUQS.shape[0]), sortUQS["uqs_initial"], 'ro', lw = 1, label = "Initial UQS")
plt.plot(np.arange(sortUQS.shape[0]), sortUQS["uqs"], 'go', lw = 1, label = "Final UQS")

plt.ylabel('Unit Quality Score')
plt.xlabel('Sentence Index')
# Out:
# Text(0.5,0,u'Sentence Index')

# %% [markdown]
# ### Plot the worker quality score (WQS) at the beginning of the process and at the end

# %% [markdown]
# #### Print the results for the workers in our dataset

# %%
results_passages_per_article_random["workers"].head(10)
# Out:
#             duration  output.relevant_snippets.count  job  judgment  unit  \
# worker
# 1853290    73.500000                        1.000000    1         2     2
# 1924522     9.000000                        1.000000    1         1     1
# 4316379    63.468750                        3.437500    1        32    32
# 6336109    54.500000                        1.000000    1         2     2
# 11131207  103.833333                        1.322222    1        90    90
# 15004831  371.000000                        2.631579    1        19    19
# 15193250   35.568627                        8.529412    1        51    51
# 15965551   46.500000                        3.066667    1        30    30
# 18386513   54.206897                        1.896552    1        29    29
# 18666417   74.423077                        2.192308    1        26    26
#
#                wqs  wqs_initial
# worker
# 1853290   0.391368     0.346234
# 1924522   0.957679     0.925836
# 4316379   0.407083     0.324687
# 6336109   0.535502     0.495549
# 11131207  0.230278     0.197061
# 15004831  0.477390     0.409545
# 15193250  0.535472     0.447713
# 15965551  0.389754     0.317597
# 18386513  0.493527     0.399914
# 18666417  0.618880     0.528134

# %%
plt.rcParams['figure.figsize'] = 15, 5

plt.subplot(1, 2, 1)
plt.hist(results_passages_per_article_random["workers"]["wqs"])
plt.ylim(0, 25)
plt.xlabel("WQS")
plt.ylabel("# Workers")

plt.subplot(1, 2, 2)
plt.hist(results_passages_per_article_random["workers"]["wqs_initial"])
plt.ylim(0, 25)
plt.xlabel("WQS Initial")
plt.ylabel("# Workers")
# Out:
# Text(0,0.5,u'# Workers')

# %% [markdown]
# ### Plot the change in worker qualtity score at the beginning of the process and at the end

# %%
sortWQS = results_passages_per_article_random["workers"].sort(['wqs'], ascending=[1])
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.

# %%
plt.rcParams['figure.figsize'] = 15, 5

plt.plot(np.arange(sortWQS.shape[0]), sortWQS["wqs_initial"], 'ro', lw = 1, label = "Initial UQS")
plt.plot(np.arange(sortWQS.shape[0]), sortWQS["wqs"], 'go', lw = 1, label = "Final UQS")

plt.ylabel('Worker Quality Score')
plt.xlabel('Worker Index')
#plt.legend(loc=9, bbox_to_anchor=(0.5, 1.2), ncol=3, prop={'size':12})
# Out:
# Text(0.5,0,u'Worker Index')

# %%
import numpy as np
import pandas as pd

results_passages_per_article_random["units"]['max_relevance_score'] = pd.Series(np.random.randn(len(results_passages_per_article_random["units"])), index=results_passages_per_article_random["units"].index)
results_passages_per_article_random["units"]['none_score'] = pd.Series(np.random.randn(len(results_passages_per_article_random["units"])), index=results_passages_per_article_random["units"].index)
results_passages_per_article_random["units"]['crowd_rel'] = pd.Series(np.random.randn(len(results_passages_per_article_random["units"])), index=results_passages_per_article_random["units"].index)

# %%
for i in xrange(0, len(results_passages_per_article_random["units"])):
    maxVal = 0.0
    found = False
    for key, value in results_passages_per_article_random["units"]["unit_annotation_score"].iloc[i].items():
        if key == "none":
            found = True
            results_passages_per_article_random["units"]['none_score'].iloc[i] = value
        else:
            if value > maxVal:
                maxVal = value
    results_passages_per_article_random["units"]['max_relevance_score'].iloc[i] = maxVal
    if found == False:
        results_passages_per_article_random["units"]['none_score'].iloc[i] = 0.0
# Out:
# /Users/oanainel/anaconda/envs/CrowdTruth2/lib/python2.7/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
gt = pd.read_csv("ground_truth_annotation.csv")

results_passages_per_article_random["units"]["reviewers_rel"] = pd.Series(np.random.randn(len(results_passages_per_article_random["units"].index)), index=results_passages_per_article_random["units"].index)
results_passages_per_article_random["units"]["reviewers_rel_merged"] = pd.Series(np.random.randn(len(results_passages_per_article_random["units"].index)), index=results_passages_per_article_random["units"].index)
results_passages_per_article_random["units"]["rel_merged"] = pd.Series(np.random.randn(len(results_passages_per_article_random["units"].index)), index=results_passages_per_article_random["units"].index)

for i in range(0, len(results_passages_per_article_random["units"].index)):
    for j in range(0, len(gt.index)):
        if (results_passages_per_article_random["units"]["input.topic"].iloc[i] == gt["topic"].iloc[j]) and (results_passages_per_article_random["units"]["input.document_id"].iloc[i] == gt["document_id"].iloc[j]):
            results_passages_per_article_random["units"]["reviewers_rel"].iloc[i] = gt["reviewers_rel"].iloc[j]
            results_passages_per_article_random["units"]["reviewers_rel_merged"].iloc[i] = gt["reviewers_rel_merged"].iloc[j]
            results_passages_per_article_random["units"]["rel_merged"].iloc[i] = gt["nist_rel_merged"].iloc[j]

# %%
results_passages_per_article_random["units"]
# Out:
#               duration  input.bin  input.doc_len  \
# unit
# 1429458914   96.200000          1            196
# 1429458915  138.466667          1            245
# 1429458916   99.600000          1            242
# 1429458918   77.333333          1            237
# 1429458919   51.800000          1            140
# 1429458920  173.533333          1            173
# 1429458921   41.933333          1            153
# 1429458922   36.800000          1            102
# 1429458923   55.200000          1            172
# 1429458924   88.333333          1             48
# 1429458925   42.466667          1            105
# 1429458926   34.266667          1             51
# 1429458927   19.200000          1             42
# 1429458928   48.733333          1            132
# 1429458929  149.266667          1            480
# 1429458930   31.333333          1             37
# 1429458931   43.666667          1             45
# 1429458932   67.333333          1            261
# 1429458933   31.200000          1            100
# 1429458934   46.133333          1            157
# 1429458935   46.800000          1            193
# 1429458936   66.666667          1            192
# 1429458937   85.333333          1            344
# 1429458938   57.866667          1            148
# 1429458939   53.000000          1            100
# 1429458940   57.600000          1             84
# 1429458941   24.600000          1            100
# 1429458942   93.000000          1             86
# 1429458943   30.800000          1             58
# 1429458944   45.466667          1            105
# ...                ...        ...            ...
# 1429460916   83.066667          2            441
# 1429460917   97.666667          2            394
# 1429460918   95.533333          2            586
# 1429460919   60.400000          2            410
# 1429460920   49.333333          2            464
# 1429460921   90.200000          2            548
# 1429460922   86.200000          2            805
# 1429460923  136.400000          2            847
# 1429460924   46.133333          2            666
# 1429460925  185.866667          2            557
# 1429460926  100.533333          2            755
# 1429460927   82.800000          2            609
# 1429460928  140.866667          2            567
# 1429460929   70.333333          2            357
# 1429460930   52.800000          2            410
# 1429460931   53.800000          2            497
# 1429460932   45.133333          2            428
# 1429460933   55.266667          2            465
# 1429460934  120.333333          2            618
# 1429460935   46.600000          2            579
# 1429460936   56.333333          2            493
# 1429460937  116.000000          2            518
# 1429460938   86.133333          2            444
# 1429460939   82.133333          2            571
# 1429460940   55.533333          2            427
# 1429460941  123.266667          2            558
# 1429460942   74.066667          2            441
# 1429460943   55.533333          2            397
# 1429460944   69.866667          2            402
# 1429460945   96.666667          2            635
#
#                                           input.document_body  \
# unit
# 1429458914  <p>A public commission ruled today that Aum Sh...
# 1429458915  <p>ABC has signed a deal to develop a televisi...
# 1429458916  <p>Japan's peace of mind was shattered anew by...
# 1429458918  <p>USA Networks Interactive, creator of the sc...
# 1429458919  <p>To the Editor:</p> <p>There is ample eviden...
# 1429458920  <p>To the Editor:</p> <p>An Oct. 6 news articl...
# 1429458921  <p>The body of a man was found yesterday float...
# 1429458922  <p>A violent gang brought boatloads of Chinese...
# 1429458923  <p>LEAD: The Indian authorities say they have ...
# 1429458924  <p>An article in Business Day on Tuesday about...
# 1429460920       Sugar Soars on Rumors Of Purchases by Mexico          161
# 1429460921      Philip W. Bonsal, 92, Last U.S. Envoy to Cuba          162
# 1429460922            What's Inequality? Ask a Former Doorman          187
# 1429460923  Economic Scene;   Blue-Collar Blues: Who Is to...          188
# 1429460924                      Shoring Up the Volunteer Army          189
# 1429460925  President Proposes $31 Billion in Education Ai...          190
# 1429460926    One Answer on College Doesn't Fit All Graduates          191
# 1429460927             From Combat To Campus On the G.I. Bill          192
# 1429460928                    The Special Education Nightmare          217
# 1429460929                   For a Few, A Revision Is Working          218
# 1429460930                      2 Teachers Tear Down the Wall          219
# 1429460931               Sound Bytes; Mainstreaming New Media          220
# 1429460932  Those Who Would Be Mayor Must Recognize Needs ...          221
# 1429460933          Synopsis of the Plight Of the Handicapped          222
# 1429460934     Iran and Iraq Offer Rival Plans for Peace Pact          247
# 1429460935  IRAN WILL RELEASE CERTAIN PRISONERS FOR ANNIVE...          248
# 1429460936  Excerpts From Letter Sent by Iraqi Official to...          249
# 1429460937  U.N. Criticized by Iranian Official Over Effor...          250
# 1429460938  Iran Rebuked by U.N. Agency For Withholding At...          251
# 1429460939               U.N. Chief Opens Talks With Iranians          252
# 1429460940  GLOBAL WARMING: Around the Globe, Big Worries ...          277
# 1429460941  Brazil Slashes Money for Project Aimed at Prot...          278
# 1429460942                       Buy Bonds, Save Rain Forests          279
# 1429460943                Half-Measures to Protect the Amazon          280
# 1429460944            Amazon Tree Cutting Better Than Burning          281
# 1429460945                  Brazil's Debt Can Save the Amazon          282
#
#             input.rel  input.topic  \
# unit
# 1429458914          1          325
# 1429458915          1          325
# 1429458916          1          325
# 1429458918          0          325
# 1429458919          0          325
# 1429458920          0          325
# 1429458921          1          362
# 1429458922          2          362
# 1429458923          2          362
# 1429458924          0          362
# 1429458925          0          362
# 1429458926          0          362
# 1429458927          1          378
# 1429458928          2          378
# 1429458929          2          378
# 1429458930          0          378
# 1429458931          0          378
# 1429458932          0          378
# 1429458933          1          350
# 1429458934          2          350
# 1429458935          1          350
# 1429458936          0          350
# 1429458937          0          350
# 1429458938          0          350
# 1429458939          2          677
# 1429458940          2          677
# 1429458941          0          677
# 1429458942          0          677
# 1429458943          1          414
# 1429458944          2          414
# ...               ...          ...
# 1429460916          1          414
# 1429460917          1          414
# 1429460918          2          414
# 1429460919          0          414
# 1429460920          0          414
# 1429460921          0          414
# 1429460922          2          690
# 1429460923          1          690
# 1429460924          0          690
# 1429460925          0          690
# 1429460926          0          690
# 1429460927          0          690
# 1429460928          1          379
# 1429460929          1          379
# 1429460930          1          379
# 1429460931          0          379
# 1429460932          0          379
# 1429460933          0          379
# 1429460934          2          330
# 1429460935          1          330
# 1429460936          1          330
# 1429460937          0          330
# 1429460938          0          330
# 1429460939          0          330
# 1429460940          1          400
# 1429460941          2          400
# 1429460942          1          400
# 1429460943          0          400
# 1429460944          0          400
# 1429460945          0          400
#
#                                       input.topic_description  \
# unit
# 1429458914  Describe a cult by name and identify the cult ...
# 1429458915  Describe a cult by name and identify the cult ...
# 1429458916  Describe a cult by name and identify the cult ...
# 1429458918  Describe a cult by name and identify the cult ...
# 1429458919  Describe a cult by name and identify the cult ...
# 1429458920  Describe a cult by name and identify the cult ...
# 1429458921             Identify incidents of human smuggling.
# 1429458922             Identify incidents of human smuggling.
# 1429458923             Identify incidents of human smuggling.
# 1429458924             Identify incidents of human smuggling.
# 1429458925             Identify incidents of human smuggling.
# 1429458926             Identify incidents of human smuggling.
# 1429458927  Identify documents that discuss opposition to ...
# 1429458928  Identify documents that discuss opposition to ...
# 1429458929  Identify documents that discuss opposition to ...
# 1429458930  Identify documents that discuss opposition to ...
# 1429458931  Identify documents that discuss opposition to ...
# 1429458932  Identify documents that discuss opposition to ...
# 1429458933  Is it hazardous to the health of individuals t...
# 1429458934  Is it hazardous to the health of individuals t...
# 1429458935  Is it hazardous to the health of individuals t...
# 1429458936  Is it hazardous to the health of individuals t...
# 1429458937  Is it hazardous to the health of individuals t...
# 1429458938  Is it hazardous to the health of individuals t...
# 1429458939  What efforts have been made to stabilize the L...
# 1429458940  What efforts have been made to stabilize the L...
# 1429458941  What efforts have been made to stabilize the L...
# 1429458942  What efforts have been made to stabilize the L...
# 1429458943  How much sugar does Cuba export and which coun...
# 1429458944  How much sugar does Cuba export and which coun...
# ...                                                       ...
# 1429460916  How much sugar does Cuba export and which coun...
# 1429460917  How much sugar does Cuba export and which coun...
# 1429460918  How much sugar does Cuba export and which coun...
# 1429460919  How much sugar does Cuba export and which coun...
# 1429460920  How much sugar does Cuba export and which coun...
# 1429460921  How much sugar does Cuba export and which coun...
# 1429460922  Find documents which describe an advantage in ...
# 1429460923  Find documents which describe an advantage in ...
# 1429460924  Find documents which describe an advantage in ...
# 1429460925  Find documents which describe an advantage in ...
# 1429460926  Find documents which describe an advantage in ...
# 1429460927  Find documents which describe an advantage in ...
# 1429460928  Identify documents that discuss mainstreaming ...
# 1429460929  Identify documents that discuss mainstreaming ...
# 1429460930  Identify documents that discuss mainstreaming ...
# 1429460931  Identify documents that discuss mainstreaming ...
# 1429460932  Identify documents that discuss mainstreaming ...
# 1429460933  Identify documents that discuss mainstreaming ...
# 1429460934  This query is looking for examples of cooperat...
# 1429460935  This query is looking for examples of cooperat...
# 1429460936  This query is looking for examples of cooperat...
# 1429460937  This query is looking for examples of cooperat...
# 1429460938  This query is looking for examples of cooperat...
# 1429460939  This query is looking for examples of cooperat...
# 1429460940  What measures are being taken by local South A...
# 1429460941  What measures are being taken by local South A...
# 1429460942  What measures are being taken by local South A...
# 1429460943  What measures are being taken by local South A...
# 1429460944  What measures are being taken by local South A...
# 1429460945  What measures are being taken by local South A...
#
#                         input.topic_query  \
# unit
# 1429458914                Cult Lifestyles
# 1429458915                Cult Lifestyles
# 1429458916                Cult Lifestyles
# 1429458918                Cult Lifestyles
# 1429458919                Cult Lifestyles
# 1429458920                Cult Lifestyles
# 1429458921                human smuggling
# 1429458922                human smuggling
# 1429458923                human smuggling
# 1429458924                human smuggling
# 1429458925                human smuggling
# 1429458926                human smuggling
# 1429458927                euro opposition
# 1429458928                euro opposition
# 1429458929                euro opposition
# 1429458930                euro opposition
# 1429458931                euro opposition
# 1429458932                euro opposition
# 1429458933  Health and Computer Terminals
# 1429458934  Health and Computer Terminals
# 1429458935  Health and Computer Terminals
# 1429458936  Health and Computer Terminals
# 1429458937  Health and Computer Terminals
# 1429458938  Health and Computer Terminals
# 1429458939          Leaning Tower of Pisa
# 1429458940          Leaning Tower of Pisa
# 1429458941          Leaning Tower of Pisa
# 1429458942          Leaning Tower of Pisa
# 1429458943           Cuba, sugar, exports
# 1429458944           Cuba, sugar, exports
# ...                                   ...
# 1429460916           Cuba, sugar, exports
# 1429460917           Cuba, sugar, exports
# 1429460918           Cuba, sugar, exports
# 1429460919           Cuba, sugar, exports
# 1429460920           Cuba, sugar, exports
# 1429460921           Cuba, sugar, exports
# 1429460922    college education advantage
# 1429460923    college education advantage
# 1429460924    college education advantage
# 1429460925    college education advantage
# 1429460926    college education advantage
# 1429460927    college education advantage
# 1429460928                  mainstreaming
# 1429460929                  mainstreaming
# 1429460930                  mainstreaming
# 1429460931                  mainstreaming
# 1429460932                  mainstreaming
# 1429460933                  mainstreaming
# 1429460934          Iran-Iraq Cooperation
# 1429460935          Iran-Iraq Cooperation
# 1429460936          Iran-Iraq Cooperation
# 1429460937          Iran-Iraq Cooperation
# 1429460938          Iran-Iraq Cooperation
# 1429460939          Iran-Iraq Cooperation
# 1429460940             Amazon rain forest
# 1429460941             Amazon rain forest
# 1429460942             Amazon rain forest
# 1429460943             Amazon rain forest
# 1429460944             Amazon rain forest
# 1429460945             Amazon rain forest
#
#                                                           job  \
# unit
# 1429458914  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458915  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458916  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458918  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458919  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458920  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458921  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458922  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458923  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458924  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458925  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458926  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458927  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458928  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458929  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458930  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458931  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458932  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458933  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458934  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458935  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458936  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458937  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458938  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458939  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458940  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458941  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458942  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458943  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429458944  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# ...                                                       ...
# 1429460916  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460917  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460918  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460919  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460920  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460921  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460922  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460923  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460924  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460925  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460926  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460927  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460928  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460929  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460930  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460931  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460932  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460933  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460934  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460935  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460936  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460937  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460938  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460939  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460940  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460941  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460942  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460943  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460944  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
# 1429460945  AnalysisFiles/2P_WithoutHighlight_Passages_Ran...
#
#                                      output.relevant_snippets  \
# unit
# 1429458914  {u's3': 13, u's2': 5, u's1': 15, u's5': 2, u's...
# 1429458915  {u'none': 1, u's3': 2, u's2': 11, u's1': 13, u...
# 1429458916  {u'none': 1, u's3': 5, u's2': 4, u's1': 3, u's...
# 1429458918  {u'none': 14, u's3': 1, u's1': 1, u's6': 1, u'...
# 1429458919  {u'none': 10, u's8': 3, u's3': 3, u's2': 4, u'...
# 1429458920        {u's3': 12, u's2': 11, u's1': 1, u's4': 11}
# 1429458921  {u's3': 5, u's2': 12, u's1': 5, u'none': 2, u'...
# 1429458922                   {u's3': 4, u's2': 15, u's1': 14}
# 1429458923  {u's3': 3, u's2': 14, u's1': 15, u's5': 15, u'...
# 1429458924                            {u'none': 14, u's1': 1}
# 1429458925                  {u's2': 1, u'none': 10, u's1': 5}
# 1429458926                            {u'none': 5, u's1': 10}
# 1429458927                            {u's1': 10, u'none': 5}
# 1429458921  {u's3': 0.333333333333, u's2': 0.8, u's1': 0.3...
# 1429458922  {u's3': 0.266666666667, u's2': 1.0, u's1': 0.9...
# 1429458923  {u's3': 0.2, u's2': 0.933333333333, u's1': 1.0...
# 1429458924  {u'none': 0.933333333333, u's1': 0.0666666666667}
# 1429458925  {u's2': 0.0666666666667, u'none': 0.6666666666...
# 1429458926   {u'none': 0.333333333333, u's1': 0.666666666667}
# 1429458927   {u's1': 0.666666666667, u'none': 0.333333333333}
# 1429458928   {u's1': 0.666666666667, u'none': 0.333333333333}
# 1429458929  {u's9': 0.6, u's8': 0.733333333333, u's3': 0.3...
# 1429458930                         {u's1': 0.6, u'none': 0.4}
# 1429458931                         {u's1': 0.6, u'none': 0.4}
# 1429458932  {u'none': 0.6, u's3': 0.333333333333, u's2': 0...
# 1429458933  {u's3': 0.933333333333, u's2': 0.333333333333,...
# 1429458934  {u's2': 0.533333333333, u's1': 0.2, u'none': 0...
# 1429458935  {u'none': 0.133333333333, u's3': 0.46666666666...
# 1429458936  {u'none': 0.666666666667, u's3': 0.13333333333...
# 1429458937  {u'none': 0.733333333333, u's8': 0.06666666666...
# 1429458938  {u'none': 0.733333333333, u's3': 0.26666666666...
# 1429458939               {u's2': 0.0666666666667, u's1': 1.0}
# 1429458940  {u's2': 0.0666666666667, u's1': 0.8, u'none': ...
# 1429458941   {u'none': 0.733333333333, u's1': 0.266666666667}
# 1429458942  {u's2': 0.0666666666667, u'none': 0.8, u's1': ...
# 1429458943                {u's2': 0.866666666667, u's1': 1.0}
# 1429458944  {u's2': 0.6, u's1': 0.266666666667, u'none': 0...
# ...                                                       ...
# 1429460916  {u's9': 0.4, u's8': 0.266666666667, u's3': 0.4...
# 1429460917  {u's9': 0.133333333333, u's8': 0.266666666667,...
# 1429460918  {u's9': 0.266666666667, u's8': 0.266666666667,...
# 1429460919  {u's9': 0.0666666666667, u's8': 0.066666666666...
# 1429460920  {u's9': 0.133333333333, u's8': 0.266666666667,...
# 1429460921  {u'none': 0.4, u's8': 0.266666666667, u's3': 0...
# 1429460922  {u's9': 0.533333333333, u's8': 0.466666666667,...
# 1429460923  {u's9': 0.4, u's8': 0.733333333333, u's13': 0....
# 1429460924  {u'none': 0.4, u's3': 0.466666666667, u's2': 0...
# 1429460925  {u's9': 0.266666666667, u's8': 0.266666666667,...
# 1429460926  {u'none': 0.2, u's8': 0.466666666667, u's13': ...
# 1429460927  {u's9': 0.6, u's8': 0.466666666667, u's3': 0.4...
# 1429460928  {u's8': 0.8, u's3': 1.0, u's2': 0.6, u's1': 0....
# 1429460929  {u's9': 0.133333333333, u's8': 0.266666666667,...
# 1429460930  {u'none': 0.0666666666667, u's8': 0.6, u's3': ...
# 1429460931  {u's9': 0.2, u's8': 0.0666666666667, u's13': 0...
# 1429460932  {u'none': 0.0666666666667, u's8': 0.8, u's3': ...
# 1429460933  {u's8': 0.0666666666667, u's3': 0.733333333333...
# 1429460934  {u's9': 0.533333333333, u's8': 0.466666666667,...
# 1429460935  {u's9': 0.533333333333, u's8': 0.6, u's13': 0....
# 1429460929             0.834675    0.117220   2.251413            2.0
# 1429460930             0.912533    0.039363   0.280924            2.0
# 1429460931             0.404012    0.537671  -0.864596            0.0
# 1429460932             0.839930    0.039363   1.617171            1.0
# 1429460933             1.000000    0.000000  -0.083666            1.0
# 1429460934             0.923799    0.034501   1.692698            2.0
# 1429460935             0.785097    0.036277  -1.038695            1.0
# 1429460936             0.962900    0.000000  -0.287842            1.0
# 1429460937             0.805437    0.194563   0.265330            0.0
# 1429460938             0.455607    0.429681   0.322041            0.0
# 1429460939             0.692671    0.189619  -0.664171            1.0
# 1429460940             0.918057    0.037100   0.521696            2.0
# 1429460941             0.962856    0.000000  -0.140827            1.0
# 1429460942             0.899612    0.100388   0.156156            2.0
# 1429460943             0.869456    0.000000  -0.243734            2.0
# 1429460944             0.893058    0.072919   0.389442            1.0
# 1429460945             0.829133    0.000000   0.862900            1.0
#
#             reviewers_rel_merged  rel_merged
# unit
# 1429458914                   1.0         1.0
# 1429458915                   1.0         1.0
# 1429458916                   1.0         1.0
# 1429458918                   0.0         0.0
# 1429458919                   0.0         0.0
# 1429458920                   1.0         0.0
# 1429458921                   1.0         1.0
# 1429458922                   1.0         1.0
# 1429458923                   1.0         1.0
# 1429458924                   0.0         0.0
# 1429458925                   0.0         0.0
# 1429458926                   0.0         0.0
# 1429458927                   0.0         1.0
# 1429458928                   0.0         1.0
# 1429458929                   1.0         1.0
# 1429458930                   0.0         0.0
# 1429458931                   0.0         0.0
# 1429458932                   0.0         0.0
# 1429458933                   1.0         1.0
# 1429458934                   1.0         1.0
# 1429458935                   1.0         1.0
# 1429458936                   0.0         0.0
# 1429458937                   0.0         0.0
# 1429458938                   0.0         0.0
# 1429458939                   1.0         1.0
# 1429458940                   1.0         1.0
# 1429458941                   0.0         0.0
# 1429458942                   0.0         0.0
# 1429458943                   1.0         1.0
# 1429458944                   1.0         1.0
# ...                          ...         ...
# 1429460916                   1.0         1.0
# 1429460917                   1.0         1.0
# 1429460918                   1.0         1.0
# 1429460919                   0.0         0.0
# 1429460920                   0.0         0.0
# 1429460921                   1.0         0.0
# 1429460922                   1.0         1.0
# 1429460923                   1.0         1.0
# 1429460924                   0.0         0.0
# 1429460925                   0.0         0.0
# 1429460926                   1.0         0.0
# 1429460927                   0.0         0.0
# 1429460928                   1.0         1.0
# 1429460929                   1.0         1.0
# 1429460930                   1.0         1.0
# 1429460931                   0.0         0.0
# 1429460932                   1.0         0.0
# 1429460933                   1.0         0.0
# 1429460934                   1.0         1.0
# 1429460935                   1.0         1.0
# 1429460936                   1.0         1.0
# 1429460937                   0.0         0.0
# 1429460938                   0.0         0.0
# 1429460939                   1.0         0.0
# 1429460940                   1.0         1.0
# 1429460941                   1.0         1.0
# 1429460942                   1.0         1.0
# 1429460943                   1.0         0.0
# 1429460944                   1.0         0.0
# 1429460945                   1.0         0.0
#
# [116 rows x 26 columns]

# %%
results_passages_per_article_random["units"].to_csv("ResultFiles/2P_WithoutHighlight_Passages_Random/units_withoutHighlight_15workers_2p_passages.csv", index=False)
